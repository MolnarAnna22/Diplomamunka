# %% [markdown]
# ## Felesleges változóktól megszűrt kommentek betöltése

# %%
import pandas as pd

# %%
#!/ usr/bin/env python
import subprocess
from os. path import isfile , join
in_path = "C:/Users/THINKPAD/Documents/"
out_path = "C:/Users/THINKPAD/OneDrive/Dokumentumok/outfiles/"
# running magyarlanc on raw corpora

#i = 0
#while i <= 2192772:
#    f = str(i) + '.txt '
#    if isfile(join(in_path, f)):
#        subprocess.call("java -Xmx1G -jar magyarlanc-3.0.jar -mode morphparse -input " + join(in_path , f) + " -output " + join(out_path , f), shell = True )
#    i += 1
print('DONE ')
# Out:
# DONE

# %%
df1 = pd.read_csv('covid1.csv', sep = ",", encoding = 'utf8', error_bad_lines=False, quotechar='"')
df2 = pd.read_csv('covid2.csv', sep = ",", encoding = 'utf8', error_bad_lines=False, quotechar='"')
df3 = pd.read_csv('covid3.csv', sep = ",", encoding = 'utf8', error_bad_lines=False, quotechar='"')
df4 = pd.read_csv('covid4.csv', sep = ",", encoding = 'utf8', error_bad_lines=False, quotechar='"')
df5 = pd.read_csv('covid5.csv', sep = ",", encoding = 'utf8', error_bad_lines=False, quotechar='"')
df6 = pd.read_csv('covid6.csv', sep = ",", encoding = 'utf8', error_bad_lines=False, quotechar='"')

# %%
df12 = df1.append(df2, ignore_index=True)
df123 = df12.append(df3, ignore_index=True)
df1234 = df123.append(df4, ignore_index=True)
df12345 = df1234.append(df5, ignore_index=True)
df_ossz = df12345.append(df6, ignore_index=True)

# %%
df_ossz.tail()
# Out:
#                                         id  \
# 2554440  1463270977176534_1463361583834140
# 2554441  3563937670371522_3564275417004414
# 2554442  3563937670371522_3564406243657998
# 2554443  3563937670371522_3564092773689345
# 2554444  3563937670371522_3564112817020674
#
#                                           Content of posts  \
# 2554440  Az a Karmelita nem egy olyan beleremegősnek tű...
# 2554441  Szerintem elöbb az eladói dolgozókat és a taná...
# 2554442  Vakcina útleveleket mikor adják már? Többen un...
# 2554443  Ibolya Novák AstraZeneca vakcinával nem lehet ...
# 2554444  Krisztina Horváth-Kovács az orosz és kínai vak...
#
#                      Created            Domain                    Keywords  \
# 2554440  2021-02-09 15:44:59  www.facebook.com                    oltáshoz
# 2554441  2021-02-09 16:39:56  www.facebook.com             vakcinák oltása
# 2554442  2021-02-09 17:53:08  www.facebook.com     Vakcina vakcinák oltása
# 2554443  2021-02-09 15:01:26  www.facebook.com  vakcinával vakcinák oltása
# 2554444  2021-02-09 15:12:34  www.facebook.com  vakcinával vakcinák oltása
#
#         Gender
# 2554440      u
# 2554441      u
# 2554442      u
# 2554443      u
# 2554444      u

# %%
adat = {}
for i in range(len(df_ossz.id)):
    adat[df_ossz.id[i]] = df_ossz["Content of posts"][i]
print(list(adat.items())[0])
# Out:
# ('10158086590232655_10158087942527655', 'Hogyan kell komolyan venni? Bezárkózni fél, 1 vagy 2 évre?\nMegvárni a vakcinát, amire sok szakember azt mondja, hogy évek kérdése, de valaki szerint fél év alatt elkészülhet? Mi lesz a klínikai 1, 2 és 3 fázissal? (Ami alapvetően hosszabbítja meg egy új vakcina előállítását)\nA vírus nem egy egyszerű nátha és nem is egy ebola.\nA karanténok hatására kevesebb volt a közlekedési baleset és különböző fertőzések sem pusztítottak úgy.\nAzonban leállt a gazdaság, aminek hatására a világon megduplázódott az éhező gyerekek száma a világon. A karantén hatására egyre több országban szaporodott meg a válások száma. A szakemberek ma már felhívják a figyelmet arra, hogy nöhet a családon belüli erőszak, az alkoholizmus ill. az öngyilkosság kockázata. Egy tanulmány szerint 28 millió műtét maradt el világszerte, amelyek szövődményei nagyon komoly következménnyel járhat.\nEgy második hullám, ami a WHO szerint hamarosan jön, valaki szerint szeptemberben, de vizionálják októberre is és nagyon halálos lesz, valóban pánikot tud kelteni az emberekben.\nValaki, aki eleve fél a vírustól, mert a korából ill. az alapbetegségeiből kiindulva fokozottan veszélyeztetett lehet.\nAki most elveszítette a munkáját, vagy retteg, hogy elveszítheti egy második hullám és amennyiben komoly korlátozások lennének, az sokkal több céget, vállalkozást vagy önkormányzati fanntartás alatt álló intézményt tehet tönkre.\nAmennyiben valaki azzal jón, hogy ezt a dolgot az 5g okozza, az meg is érdemli a dolgot.\nDe engedtessék meg azoknak az embereknek kritikát megfogalmazni, akik nagyon nehéz helyzetbe kerültek és kerülhetnek.\nÉs októberben vagy novemberben már nem lesz az az opció, hogy menjenek a földekre dolgozni. Na igen, mert ott eddig soha senki sem dolgozott és minden munkaeröt felszív.')

# %%
rev_multidict = {}
for key, value in adat.items():
    rev_multidict.setdefault(value, set()).add(key)

#[key for key, values in rev_multidict.items() if len(values) > 1]
toremove_all = [list(values) for key, values in rev_multidict.items() if len(values) > 1] # így bekerül a listába az összes ismétlődés, de abból az egyiket szeretnénk megtartani
for i in range(len(toremove_all)):
    del toremove_all[i][-1] #így mindig kiszedünk a duplikációk közül egyet, ami bent marad

# %%
toremove_all[0]
# Out:
# ['3841403015921428_3841850549210008',
#  '3861629440554940_3861957453855472',
#  '5026668104072536_5043313609074652',
#  '3991992297518338_3992067077510860',
#  '10158872344157899_10158872619627899',
#  '3939669309428131_3939680196093709',
#  '238211364642426_758764208179168',
#  '3881772558540307_3881999335184296',
#  '10158995448007048_10158995618617048',
#  '3834605439893900_3834634289891015',
#  '3593703680648354_3597214976963891',
#  '10157599953216817_10157600386996817',
#  '4990079964398017_5001340323271981',
#  '4324577097557664_4326405520708155',
#  '3503169393094712_3503361983075453',
#  '3698289256905031_3698401893560434',
#  '3929094003818995_3929699433758452',
#  '178089357001539_178099630333845',
#  '3632948780129628_3632966256794547',
#  '1665636253641102_1665765730294821',
#  '2857714634492111_2858540114409563',
#  '3946075798776655_400477981294833',
#  '3868006423238979_3870549599651328',
#  '3546803502065948_3547043902041908',
#  '10159310243617743_10159310525367743',
#  '4863324847073530_4863575260381822',
#  '3575203335861822_3575252062523616',
#  '5097622540310009_5098385910233672',
#  '3517113638416620_3517282781733039',
#  '4145801005453173_4148816568484950',
#  '4712890245448618_4713885215349121',
#  '3774575409232634_3775372005819641',
#  '4893454890679713_4893509937340875',
#  '3923385991062022_3923399554393999',
#  '4207112209303830_4207419669273084',
#  '3637670686340395_3643951032379027',
#  '4874347922637889_4877733335632681',
#  '3536077443129991_3536190733118662',
#  '894766917990718_895383691262374',
#  '164567995340097_164575212006042',
#  '2858761681068064_2859371977673701',
#  '247352766874952_247372386872990',
#  '229475432182686_229628142167415',
#  '3621163601307361_464993691165112',
#  '2396320210671165_2396874750615711',
#  '2858005014427978_2859612374267242',
#  '4874364632636218_4874503749288973',
#  ...]

# %%
df_ossz.index[df_ossz.id == '3394960137220799_3395988493784630']
# Out:
# Int64Index([241208], dtype='int64')

# %%
df_ossz["Content of posts"][241208]
# Out:
# 'https://kvm17.blogspot.com/2020/06/ertelmetlen-vakcina-es-kodos-masodik.html'

# %%
df_ossz.index[df_ossz.id == '10158342543064346_10158346069524346']
# Out:
# Int64Index([303], dtype='int64')

# %%
df_ossz["Content of posts"][303]
# Out:
# 'https://kvm17.blogspot.com/2020/06/ertelmetlen-vakcina-es-kodos-masodik.html'

# %%
len(toremove_all) #összesen ennyiféle egyező van
# Out:
# 23320

# %%
toremove = []
for i in range(len(toremove_all)):
    for j in range(len(toremove_all[i])):
        toremove.append(toremove_all[i][j])
len(toremove) ## ennyi kommentet lehet törölni dublikáció miatt
# Out:
# 137518

# %%
df_nodupl = df_ossz[~df_ossz["id"].isin(toremove)]
df_nodupl = df_nodupl.reset_index(drop=True)
df_nodupl.shape
# Out:
# (2416927, 6)

# %%
txt_length = []
for i in range(len(df_nodupl["Content of posts"])):
    txt_length.append(len(str(df_nodupl["Content of posts"][i]).split()))

# %%
egyszo = 0
for i in txt_length:
    if i == 1:
        egyszo +=1
print(egyszo)
# Out:
# 41528

# %%
sokszo = 0
for i in txt_length:
    if i > 100:
        sokszo += 1
print(sokszo)
# Out:
# 50306

# %%
kevesszo = 0
for i in txt_length:
    if i < 5:
        kevesszo +=1
print(kevesszo)
# Out:
# 334363

# %% [markdown]
# ### A 4 szónál hosszabb és maximum 100 szavas kommentek betöltése

# %%
df = pd.read_csv('del_length (1).csv', sep = ",", encoding = 'utf8', error_bad_lines=False, quotechar='"')

# %%
df
# Out:
#                                         id  \
# 0        1866276730170800_1866679230130550
# 1        1188841988144997_1188958054800057
# 2        1188841988144997_1188958114800051
# 3        1188841988144997_1188967994799063
# 4        1188841988144997_1188982634797599
# ...                                    ...
# 2192768  1463270977176534_1463361583834140
# 2192769  3563937670371522_3564275417004414
# 2192770  3563937670371522_3564406243657998
# 2192771  3563937670371522_3564092773689345
# 2192772  3563937670371522_3564112817020674
#
#                                           Content of posts  \
# 0        Hisszuk vagy nem az ellenszer mar meg van csak...
# 1        Klára Pásztor-Búza Igeen és különösen az időse...
# 2        Kedves Tünde! Attol, hogy CF-ek vagyunk, meg v...
# 3        Egyébként mi az h ha lefogyunk jöhet a gyerek?...
# 4        Boda Tündi  Szerintem told el a bicajt. Te aka...
# ...                                                    ...
# 2192768  Az a Karmelita nem egy olyan beleremegősnek tű...
# 2192769  Szerintem elöbb az eladói dolgozókat és a taná...
# 2192770  Vakcina útleveleket mikor adják már? Többen un...
# 2192771  Ibolya Novák AstraZeneca vakcinával nem lehet ...
# 2192772  Krisztina Horváth-Kovács az orosz és kínai vak...
#
#                      Created            Domain  \
# 0        2020-04-01 05:52:49  www.facebook.com
# 1        2020-07-01 16:07:51  www.facebook.com
# 2        2020-07-01 16:07:57  www.facebook.com
# 3        2020-07-01 16:23:18  www.facebook.com
# 4        2020-07-01 16:47:29  www.facebook.com
# ...                      ...               ...
# 2192768  2021-02-09 15:44:59  www.facebook.com
# 2192769  2021-02-09 16:39:56  www.facebook.com
# 2192770  2021-02-09 17:53:08  www.facebook.com
# 2192771  2021-02-09 15:01:26  www.facebook.com
# 2192772  2021-02-09 15:12:34  www.facebook.com
#
#                                                   Keywords  \
# 0        https://www.origo.hu/tudomany/20200331-a-fel-v...
# 1                                                oltásokat
# 2                                                oltásokat
# 3                                                oltásokat
# 4                                                oltásokat
# ...                                                    ...
# 2192768                                           oltáshoz
# 2192769                                    vakcinák oltása
# 2192770                            Vakcina vakcinák oltása
# 2192771                         vakcinával vakcinák oltása
# 2192772                         vakcinával vakcinák oltása
#
#                                               text_nopunct
# 0        Hisszuk vagy nem az ellenszer mar meg van csak...
# 1        Klára Pásztor Búza Igeen és különösen az időse...
# 2        Kedves Tünde Attol hogy CF ek vagyunk meg van ...
# 3        Egyébként mi az h ha lefogyunk jöhet a gyerek ...
# 4        Boda Tündi Szerintem told el a bicajt Te akars...
# ...                                                    ...
# 2192768  Az a Karmelita nem egy olyan beleremegősnek tű...
# 2192769  Szerintem elöbb az eladói dolgozókat és a taná...
# 2192770  Vakcina útleveleket mikor adják már Többen unj...
# 2192771  Ibolya Novák AstraZeneca vakcinával nem lehet ...
# 2192772  Krisztina Horváth Kovács az orosz és kínai vak...
#
# [2192773 rows x 6 columns]

# %%
df["date"] = df["Created"].str[:7]

# %%
df.tail()
# Out:
#                                         id  \
# 2192768  1463270977176534_1463361583834140
# 2192769  3563937670371522_3564275417004414
# 2192770  3563937670371522_3564406243657998
# 2192771  3563937670371522_3564092773689345
# 2192772  3563937670371522_3564112817020674
#
#                                           Content of posts  \
# 2192768  Az a Karmelita nem egy olyan beleremegősnek tű...
# 2192769  Szerintem elöbb az eladói dolgozókat és a taná...
# 2192770  Vakcina útleveleket mikor adják már? Többen un...
# 2192771  Ibolya Novák AstraZeneca vakcinával nem lehet ...
# 2192772  Krisztina Horváth-Kovács az orosz és kínai vak...
#
#                      Created            Domain                    Keywords  \
# 2192768  2021-02-09 15:44:59  www.facebook.com                    oltáshoz
# 2192769  2021-02-09 16:39:56  www.facebook.com             vakcinák oltása
# 2192770  2021-02-09 17:53:08  www.facebook.com     Vakcina vakcinák oltása
# 2192771  2021-02-09 15:01:26  www.facebook.com  vakcinával vakcinák oltása
# 2192772  2021-02-09 15:12:34  www.facebook.com  vakcinával vakcinák oltása
#
#                                               text_nopunct     date
# 2192768  Az a Karmelita nem egy olyan beleremegősnek tű...  2021-02
# 2192769  Szerintem elöbb az eladói dolgozókat és a taná...  2021-02
# 2192770  Vakcina útleveleket mikor adják már Többen unj...  2021-02
# 2192771  Ibolya Novák AstraZeneca vakcinával nem lehet ...  2021-02
# 2192772  Krisztina Horváth Kovács az orosz és kínai vak...  2021-02

# %%
df[df["date"] == "2020-01"]["Content of posts"]
# Out:
# 373       Zoli oltásai jók voltak,de az az ing és mellén...
# 443       UK.ben élek,Londonban egy arab negyedben. Láto...
# 891       Próbálkoztak vajon poroltással is ? Tudjátok, ...
# 1140      Javaslom kivinni az oltáshoz (saját pénzén/ eg...
# 1510      Ágoston Dienes hoppá!!! Ez ám az oltás😂😂😂 Rád ...
#                                 ...
# 223217    Az első méhnyakrák elleni védőoltás pályázatot...
# 223257    Mi is pontosan az immunologiailag karosodott ?...
# 223312                            Nagyon aranyos vagy!!!!!!
# 223467                     Gabriella Kiss Jajj de gyönyörű❤
# 223468      Andrea Barcza végre egy fellellős gazdi!!!!!!!!
# Name: Content of posts, Length: 10789, dtype: object

# %%
print("2020.január: " + str(df[df["date"] == "2020-01"].shape))
print("2020.február: " + str(df[df["date"] == "2020-02"].shape))
print("2020.március: " + str(df[df["date"] == "2020-03"].shape))
print("2020.április: " + str(df[df["date"] == "2020-04"].shape))
print("2020.május: " + str(df[df["date"] == "2020-05"].shape))
print("2020.június: " + str(df[df["date"] == "2020-06"].shape))
print("2020.július: " + str(df[df["date"] == "2020-07"].shape))
print("2020.augusztus: " + str(df[df["date"] == "2020-08"].shape))
print("2020.szeptember: " + str(df[df["date"] == "2020-09"].shape))
print("2020.október: " + str(df[df["date"] == "2020-10"].shape))
print("2020.november: " + str(df[df["date"] == "2020-11"].shape))
print("2020.december: " + str(df[df["date"] == "2020-12"].shape))
print("2021.január: " + str(df[df["date"] == "2021-01"].shape))
print("2021.február: " + str(df[df["date"] == "2021-02"].shape))
# Out:
# 2020.január: (10789, 7)
# 2020.február: (8239, 7)
# 2020.március: (22974, 7)
# 2020.április: (28915, 7)
# 2020.május: (25678, 7)
# 2020.június: (19579, 7)
# 2020.július: (19314, 7)
# 2020.augusztus: (46253, 7)
# 2020.szeptember: (43888, 7)
# 2020.október: (80849, 7)
# 2020.november: (237965, 7)
# 2020.december: (500788, 7)
# 2021.január: (960577, 7)
# 2021.február: (186965, 7)

# %%
date_list = ["2020.január", "2020.február", "2020.március", "2020.április", "2020.május", "2020.június", "2020.július",
            "2020.augusztus", "2020.szeptember", "2020.október", "2020.november", "2020.december", "2021.január", "2021.február"]
number_list = [10789, 8239, 22974, 28915, 25678, 19579, 19314, 46253, 43888, 80849, 237965, 500788, 960577, 186965]
date_202010 = ["2020.január", "2020.február", "2020.március", "2020.április", "2020.május", "2020.június", "2020.július",
            "2020.augusztus", "2020.szeptember", "2020.október"]
number_202010 = [10789, 8239, 22974, 28915, 25678, 19579, 19314, 46253, 43888, 80849]
date_202102 = ["2020.november", "2020.december", "2021.január", "2021.február"]
number_202102 = [237965, 500788, 960577, 186965]

# %%
import matplotlib.pyplot as plt

degrees = 70
plt.xticks(rotation=degrees)
plt.plot(date_list, number_list)

# %%
degrees = 70
plt.xticks(rotation=degrees)
plt.plot(date_202010, number_202010)

# %%
degrees = 70
plt.xticks(rotation=degrees)
plt.plot(date_202102, number_202102)

# %%
df_202002_202101 = df[(df["date"] != "2020-01") & (df["date"] != "2021-02")]

# %%
df_202002_202101 = df_202002_202101.reset_index(drop = True)

# %%
for j in range(len(df_202002_202101)):
    text_file = open(in_path + str(j) + ".txt", "w", encoding = "utf8")
    text_file.write(df_202002_202101["text_nopunct"][j])
    
text_file.close()

# %%
text_file.close()

# %%
text_file = open(in_path + "covid_szavak" + ".txt", "w", encoding = "utf8")

for i in range(20000):
    text_file.write(df_202002_202101["text_nopunct"][i] + " @@@ ")
    
text_file.close()

# %%
text_file.close()

# %%
file = pd.read_fwf(in_path + "covid.txt", delimiter = " @@@ ", encoding = "utf8", header = None)

file
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-50-166dfb286f9d> in <module>
# ----> 1 file = pd.read_fwf(in_path + "covid.txt", delimiter = " @@@ ", encoding = "utf8", header = None)
#       2
#       3 file
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in read_fwf(filepath_or_buffer, colspecs, widths, infer_nrows, **kwds)
#     846     kwds["infer_nrows"] = infer_nrows
#     847     kwds["engine"] = "python-fwf"
# --> 848     return _read(filepath_or_buffer, kwds)
#     849
#     850
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     458
#     459     try:
# --> 460         data = parser.read(nrows)
#     461     finally:
#     462         parser.close()
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in read(self, nrows)
#    1196     def read(self, nrows=None):
#    1197         nrows = _validate_integer("nrows", nrows)
# -> 1198         ret = self._engine.read(nrows)
#    1199
#    1200         # May alter columns / col_dict
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in read(self, rows)
#    2584
#    2585         alldata = self._rows_to_cols(content)
# -> 2586         data = self._exclude_implicit_index(alldata)
#    2587
#    2588         columns = self._maybe_dedup_names(self.columns)
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in _exclude_implicit_index(self, alldata)
#    2595
#    2596     def _exclude_implicit_index(self, alldata):
# -> 2597         names = self._maybe_dedup_names(self.orig_names)
#    2598
#    2599         if self._implicit_index:
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in _maybe_dedup_names(self, names)
#    1649
#    1650             for i, col in enumerate(names):
# -> 1651                 cur_count = counts[col]
#    1652
#    1653                 while cur_count > 0:
#
# MemoryError:

# %% [markdown]
# ### Különleges karakterek törlése

# %%
punctuation = "'^&*_+<>?:„;"
df["Content of posts"] = [''.join(c for c in s if c not in punctuation) for s in df["Content of posts"]]

# %%
df["Content of posts"][4]
# Out:
# 'Boda Tündi\n\nSzerintem told el a bicajt.\nTe akarsz puttonyt mi nem ennyi.\nMi így gondoljuk,20-30 évig tartó rabszolgaság,költeni kell rá,figyelni nevelni állandóan.\nRámegy az életed a kölökre,plusz meg se érem eleve a felnőtt korát sem,ilyen világba.Duplán rá..szás.\nEgy perc nyugtod sincs,nem mehetünk oda ahova csak akarunk.\nÁllandóan egy kis gyerekhez igazíts mindent, rendelj alá mindent.\n\nInkább a halál, amúgy megkapom az ,,igazi érzelmeket" hidd el meg sokan mások.\nEllenben nem állunk be a sorba fialni mert ezt várja el a társadalom.'

# %% [markdown]
# ### Szövegben \n-ek kicserélése sima szóközre

# %%
table = df.replace(r'\n', ' ', regex=True)

# %%
table["Content of posts"][4]
# Out:
# 'Boda Tündi  Szerintem told el a bicajt. Te akarsz puttonyt mi nem ennyi. Mi így gondoljuk,20-30 évig tartó rabszolgaság,költeni kell rá,figyelni nevelni állandóan. Rámegy az életed a kölökre,plusz meg se érem eleve a felnőtt korát sem,ilyen világba.Duplán rá..szás. Egy perc nyugtod sincs,nem mehetünk oda ahova csak akarunk. Állandóan egy kis gyerekhez igazíts mindent, rendelj alá mindent.  Inkább a halál, amúgy megkapom az ,,igazi érzelmeket" hidd el meg sokan mások. Ellenben nem állunk be a sorba fialni mert ezt várja el a társadalom.'

# %% [markdown]
# ### Dupla space kicserélése egyre

# %%
table = table.replace('  ', ' ', regex=True)

# %%
table["Content of posts"][1][137]
# Out:
# '😂'

# %%
table["Content of posts"][0].split()
# Out:
# ['Hisszuk',
#  'vagy',
#  'nem',
#  'az',
#  'ellenszer',
#  'mar',
#  'meg',
#  'van',
#  'csak',
#  'meg',
#  'varnak',
#  'vele',
#  'hogy',
#  'meg',
#  'sulyosabb',
#  'legyen',
#  'a',
#  'helyzet',
#  'es',
#  'akkor',
#  'elo',
#  'allnak',
#  'vele',
#  'mert',
#  'akkor',
#  'jobban',
#  'el',
#  'tudjak',
#  'adni',
#  'ez',
#  'is',
#  'penz',
#  'vkinek.',
#  'Ne',
#  'gondoljak,hogy',
#  'veletlenul',
#  'fognak',
#  'rajonni,hogy',
#  'mi',
#  'a',
#  'leghatasosabb',
#  'a',
#  'virus',
#  'ellen.']

# %%
import codecs
accent = ['á', 'é', 'í', 'ó', 'ö', 'ő', 'ú', 'ü', 'ű']

accented = {}
for i in range(len(df["Content of posts"])):
    accented[str(i)] = 0

# %%
len(accented)
# Out:
# 2030479

# %%
for j in accent:
    for i in range(len(df["Content of posts"])):
        if j in df["Content of posts"][i]:
            accented[str(i)] += df["Content of posts"][i].count(j)
        else:
            accented[str(i)] += 0

# %%
list(accented.values())[:20]
# Out:
# [0, 10, 1, 13, 32, 39, 24, 22, 8, 15, 11, 6, 44, 3, 2, 8, 5, 4, 1, 20]

# %%
from collections import Counter

print(Counter(list(accented.values())).keys()) # equals to list(set(words))
print(Counter(list(accented.values())).values())
# Out:
# dict_keys([0, 30, 1, 13, 32, 39, 24, 22, 8, 15, 11, 6, 44, 3, 2, 5, 4, 20, 21, 7, 25, 12, 9, 56, 31, 10, 34, 40, 19, 60, 17, 57, 16, 18, 35, 14, 27, 26, 37, 43, 28, 41, 29, 36, 66, 47, 53, 79, 50, 49, 33, 52, 46, 23, 38, 54, 42, 51, 45, 48, 58, 55, 62, 61, 70, 82, 65, 63, 64, 68, 67, 74, 71, 73, 59, 72, 76, 81, 69, 78, 88, 92, 75, 77, 85, 104, 84, 86, 83, 89, 98, 80, 90, 103, 94, 116, 87, 115, 93, 96, 107, 102, 114, 97, 91, 101, 109, 95])
# dict_values([135859, 7427, 140067, 43299, 6226, 3653, 12667, 14797, 95377, 33066, 58430, 136317, 2432, 197074, 187599, 161020, 184472, 18520, 16549, 113815, 11285, 50008, 80302, 650, 6702, 67507, 5291, 3321, 20484, 388, 25773, 596, 29179, 23103, 4817, 37704, 9332, 10230, 3991, 2594, 8497, 3033, 7875, 4490, 154, 1712, 953, 26, 1338, 1507, 5608, 1114, 1995, 13735, 3831, 875, 2784, 1153, 2182, 1552, 536, 779, 310, 343, 93, 14, 213, 287, 206, 128, 133, 47, 83, 60, 452, 68, 36, 15, 96, 28, 3, 3, 54, 44, 12, 3, 10, 9, 13, 2, 2, 21, 7, 2, 3, 1, 7, 2, 2, 1, 2, 1, 2, 2, 4, 1, 1, 1])

# %%
import matplotlib.pyplot as plt
import seaborn as sns

fig, ax = plt.subplots()
sns.distplot(list(accented.values()), ax=ax, hist=True, kde=False, 
             bins=range(31), color = 'blue',
             hist_kws={'edgecolor':'black'})
ax.set_xlim(0, 31)
ax.set_xticks(range(31))
plt.show()

# %%
nulla = []
for (key, value) in accented.items():
    if value == 0:
        nulla.append(key)

# %%
for i in range(len(nulla)):
    nulla[i] = int(nulla[i])

# %%
hossz = []
for i in nulla:
    hossz.append(table["txt_length"][i])

# %%
import statistics
statistics.mean(hossz)
# Out:
# 14

# %%
statistics.stdev(hossz)
# Out:
# 13.856406460551018

# %%
fig, ax = plt.subplots()
sns.distplot(hossz, ax=ax, hist=True, kde=False, 
             bins=range(31), color = 'blue',
             hist_kws={'edgecolor':'black'})
ax.set_xlim(5, 31)
ax.set_xticks(range(5, 31))
plt.show()

# %%
egy = []
for (key, value) in accented.items():
    if value == 1:
        egy.append(key)

# %%
for i in range(len(egy)):
    egy[i] = int(egy[i])

# %%
hossz_egy = []
for i in egy:
    hossz_egy.append(table["txt_length"][i])

# %%
statistics.mean(hossz_egy)
# Out:
# 9

# %%
statistics.stdev(hossz_egy)
# Out:
# 9.273618495495704

# %%
fig, ax = plt.subplots()
sns.distplot(hossz_egy, ax=ax, hist=True, kde=False, 
             bins=range(31), color = 'blue',
             hist_kws={'edgecolor':'black'})
ax.set_xlim(5, 31)
ax.set_xticks(range(5, 31))
plt.show()

# %% [markdown]
# ## Tokenizálás, lemmatizálás

# %%
df_202002_202101.to_csv("df_202002_202101.csv", index = False)

# %%
import hu_core_ud_lg

nlp = hu_core_ud_lg.load()
# Out:
# C:\Users\THINKPAD\Anaconda3\lib\site-packages\spacy\util.py:275: UserWarning: [W031] Model 'hu_core_ud_lg' (0.3.1) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.5). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)

# %% [markdown]
# ### Csak a melléknevek, igék, főnevek, tulajdonnevek, határozószavak, számok maradnak

# %% [markdown]
# #### Ezenkívül töröltem azokat a szavakat, amik benne vannak a stoplistában és amik nem betűkből állnak (pl. számok, emojik)

# %%
allowed = ['ADV', 'VERB', 'NOUN', 'ADJ', 'NUM', 'PROPN']

kommentek = []
for txt in table["Content of posts"]:
    doc = nlp(txt)
    proc = []
    for token in doc:
        if token.is_alpha and token.pos_ in allowed and not token.is_stop:
            proc.append(str(token.lemma_).lower())
    txt = ' '.join(proc)
    kommentek.append(txt)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-150729c4dd77> in <module>
#       4
#       5 kommentek = []
# ----> 6 for txt in table["Content of posts"]:
#       7     doc = nlp(txt)
#       8     proc = []
#
# NameError: name 'table' is not defined

# %% [markdown]
# ### Ezeket a lemmatizált kommenteket is hozzávettem a dataframe-hez és kimentettem egy új fájlba

# %%
table_token = pd.read_csv("tokenized_comments_noverb.csv", sep = ",", encoding = 'utf8', error_bad_lines=False, quotechar='"')

# %%
table_token.head()
# Out:
#                                   id  \
# 0  1866276730170800_1866679230130550
# 1  1188841988144997_1188958054800057
# 2  1188841988144997_1188958114800051
# 3  1188841988144997_1188967994799063
# 4  1188841988144997_1188982634797599
#
#                                     Content of posts              Created  \
# 0  Hisszuk vagy nem az ellenszer mar meg van csak...  2020-04-01 05:52:49
# 1  Klára Pásztor-Búza Igeen és különösen az időse...  2020-07-01 16:07:51
# 2  Kedves Tünde! Attol, hogy CF-ek vagyunk, meg v...  2020-07-01 16:07:57
# 3  Egyébként mi az h ha lefogyunk jöhet a gyerek?...  2020-07-01 16:23:18
# 4  Boda Tündi  Szerintem told el a bicajt. Te aka...  2020-07-01 16:47:29
#
#              Domain                                           Keywords  \
# 0  www.facebook.com  https://www.origo.hu/tudomany/20200331-a-fel-v...
# 1  www.facebook.com                                          oltásokat
# 2  www.facebook.com                                          oltásokat
# 3  www.facebook.com                                          oltásokat
# 4  www.facebook.com                                          oltásokat
#
#                                         text_nopunct     date  \
# 0  Hisszuk vagy nem az ellenszer mar meg van csak...  2020-04
# 1  Klára Pásztor Búza Igeen és különösen az időse...  2020-07
# 2  Kedves Tünde Attol hogy CF ek vagyunk meg van ...  2020-07
# 3  Egyébként mi az h ha lefogyunk jöhet a gyerek ...  2020-07
# 4  Boda Tündi Szerintem told el a bicajt Te akars...  2020-07
#
#                                            kommentek
# 0  hisszuk ellenszer var sulyosabb helyzet penz v...
# 1                 klára igeen különös idősebb gyerek
# 2  tünde attol emiatt igazan aggodalmaskodn igazi...
# 3  egyébként gyerek súly kötve vékony gyerek kövé...
# 4  boda tündi szerintem bicaj puttony év tartó ra...

# %% [markdown]
# ### Ékezetes karakterek aránya

# %%
import codecs
accent = ['á', 'é', 'í', 'ó', 'ö', 'ő', 'ú', 'ü', 'ű']

accented = {}
for i in range(len(table_token["kommentek"])):
    accented[str(i)] = 0

# %% [markdown]
# #### Szótárba kiszedtem, hogy melyik kommentben hány ékezetes betű található

# %%
for i in range(len(table_token["kommentek"])):
    for j in accent:
        if j in str(table_token["kommentek"][i]):
            accented[str(i)] += 1
        else:
            accented[str(i)] += 0

# %% [markdown]
# #### Illetve megnéztem azt is, hogy maximálisan hány ékezet szerepelt a szövegekben, illetve az egyes ékezetmennyiségnek milyen volt az előfordulása

# %%
from collections import Counter

print(Counter(list(accented.values())).keys()) # equals to list(set(words))
print(Counter(list(accented.values())).values())
# Out:
# dict_keys([0, 4, 1, 3, 8, 6, 5, 7, 2, 9])
# dict_values([281766, 233407, 414088, 337144, 15291, 90014, 152120, 44253, 424463, 2473])

# %% [markdown]
# 281760 szövegben egyáltalán nem volt ékezet

# %%
import matplotlib.pyplot as plt
import seaborn as sns

fig, ax = plt.subplots()
sns.distplot(list(accented.values()), ax=ax, hist=True, kde=False, 
             bins=range(11), color = 'blue',
             hist_kws={'edgecolor':'black'})
ax.set_xlim(0, 11)
ax.set_xticks(range(11))
plt.show()

# %%
len(accented)
# Out:
# 1995019

# %% [markdown]
# ### Töröljük azokat, ahol üres a komment

# %%
table_new = table_token.drop(table_token[table_token["kommentek"].isna()].index)

# %%
table_new = table_new.reset_index(drop=True)

# %%
table_new.shape
# Out:
# (1955342, 8)

# %%
import nltk
import itertools
txt = list(table_new["kommentek"])

txts = []
for t in txt:
    txts.append(t.strip().split())
words_sigbig = list(itertools.chain(*txts))

b = (pd.Series(nltk.ngrams(words_sigbig, 2)).value_counts())[:1000]
bigrams = b.index.tolist()

# %%
of = codecs.open('significant_bigrams_2021_covid.tsv', 'w', 'utf-8')
for e in bigrams:
    exp = e[0] + ' ' + e[1] + "\t" + e[0] + "_" + e[1] + '\n'
    of.write(exp)
of.close()

# %%
f = codecs.open('significant_bigrams_2021_covid.tsv', 'r', 'utf-8') # a szerkesztett verziót hívd be!!

bigrams = []
for l in f:
    w1, w2 = l.strip().split('\t')
    tup = w1,w2
    bigrams.append(tup)

def filter_bigrams(text):
    text = " " + text + " "
    for i in bigrams:
        text = text.replace(" " + i[0] + " ", " " + i[1] + " " )
    return text

sigbigrams = []
for komment in list(table_new["kommentek"]):
    sigbigrams.append(filter_bigrams(komment))

# %%
sigbigrams
# Out:
# [' hisszuk ellenszer var sulyosabb helyzet penz vki veletlen rajonni leghatasosabb ',
#  ' klára igeen különös idősebb gyerek ',
#  ' tünde attol emiatt igazan aggodalmaskodn igazi erzelem eleg jol azer alkalomadtan nez kor csonka csal szo igazi erzelem gyerek ',
#  ' egyébként gyerek súly kötve vékony gyerek kövér dddd ',
#  ' boda tündi szerintem bicaj puttony év tartó rabszolgaság állandóan rámegy élet kölö érem eleve felnőtt kor világ duplán szás perc nyugt ahova állandóan kis gyerek igazíts halál amúgy igazi érzelem sokan ellenben sor társadalom ',
#  ' krisztian köhalmi köz rettegés óvatosság szó éves anyuka fia férj védőoltás egészséges_ember kivizsgálatlan anyuka naponta piac család tömeg rossz emb lehülyéz biztonság család makg ',
#  ' makár papp katalin önző döntés mellesleg gyerek szinonima csemete ifjonc lurkó kölyök gyermek poronty pulya purdé apróság utód csöppség sarj gyerkőc baba emberpalánta csimot kööl tökmag kicsi pici hátulgombolós bébi srác ',
#  ' edina túlsúly fogamzás mellesleg nő gyerek hülyé gyerek utáni vágy irányíthatatlan érzés önrendelkezés ',
#  ' tamásné csillahó érzés ',
#  ' boda tündi ugyanitt pszichológiai tanácsadás szabad_akarat gyermek boldogok ingyenes felsorolt élelmiszer csok igényelhető ',
#  ' boda tündi mellesleg éves korán mégis mid kereset ingatlan tartalék stabil párkapcsolat ugye ',
#  ' addigra vakcinàt állandó cirkusz erő kitartás ',
#  ' kocsisné boros mónika pánik külön betegség influenza_védőoltás döntés beoltat oltás erőteljes fájdalom kitartó láz veszélyes újonnan megjelent vírus józan óvatosság különbség vicc olasz spanyol kórház folyosó föld oxigén palack lélegző ember ',
#  ' párna ',
#  ' márk füri macso ettol ferfi rossz szoveg pride hely ',
#  ' kísérleti vakcina_mellékhatás utólag ',
#  ' cintia volentér vita ',
#  ' hitvány nyugdíj bill and melinda gates alapította gyártótól senki világon vásároljon semmilyen vakcinát kereskedjen azokkal akiknek adott nyilatkozatával elsőbbséget ',
#  ' erika pávlicz ohh okos influenza viddz ev megis ra oltas jonni flegmassg ertelmezes ',
#  ' balázsné edina influenz köz védőoltás influenza hogan okoskodsz első védőoltás hiába ellenszer influenz ezer korona ',
#  ' rózsi véghelyi józsefné egyáltalán rossz sokan válasz végig vakcina írva végzettség lényeg elővigyázatos pánik felesleges túlgondolás mindmeghal életérzés semmire ',
#  ' öszterling bernad vakcina ösz merkely prof ',
#  ' szász krisztina magyar_ember kár rosszindulat negativitás oltóanyag ',
#  ' szóval tájékozódjat hova ',
#  ' tengeri malac ',
#  ' józsefné grób örökre zár max oltás garantált egyelör biztos hatásos mindenk lefolyás sokáig ',
#  ' lajosné sasvári baj oltoanyag ',
#  ' zsuzsa csíkos mért ök csinálnak kamu virusal durva ',
#  ' márk dabronci gyìkember ',
#  ' márk dabronci elmúlt_év ember ijesztgetés ',
#  ' tagadás hívő vélemény máshogy vélekedés elő liba máshogy ütni vágni gyallázni aljas közönséges ellenség szemlélet gondolatvilág jellemükből céljuk sok kívánják hátuk közepére válasszák ',
#  ' lajos jech ',
#  ' oltás addig ',
#  ' gyógyszer jó üzlet ',
#  ' veszettség elleni_oltás papagáj ',
#  ' lopás hivatalos mód fidesz vagyon ',
#  ' rozika törzsök szöginé jakab ferenc kormány okos ',
#  ' jakab első átbaszta ember rémlik tavasz felesleges maszk_viselés beteg azóta fidesz ',
#  ' tünde kohajda vég ',
#  ' tessék dán oldal extra gond ugyanoly mellékhatás elő oltás világ ',
#  ' dán egészségügyi hatóság kampány hpv oltás ',
#  ' add ',
#  ' gyerekem biztos ',
#  ' tuti otthon ',
#  ' tauzin balázsné kárpáti alexandra ',
#  ' itthon ',
#  ' gyerek kísérleti_nyúl tuti ',
#  ' kötelező_oltás ',
#  ' boda tündi frász ',
#  ' boda tündi rendes adó csok köszike bő kikövetelem épp órás alvás ',
#  ' alexandra tiszta fogalom környezet gyerektel egyedülálló nő hangoztatjú ',
#  ' makár papp katalin hölgyi rossz ajtó tudatos gyerektel ember dolog csodás érzés gyerek elfogadás csodálatos pozitív tulajdonság ',
#  ' alexandra kulcsszó boldog élet ',
#  ' boda tündi menny haza csa ',
#  ' boda tündi menjél ',
#  ' beteg ',
#  ' privát infó ',
#  ' vitamin védőoltás ',
#  ' gyulán kiss őszig vège járváz vakcina se addigra ',
#  ' népirtás először parlamenti_képviselő hülyeség ',
#  ' au gyerek kísérleti_patkány huuu komolyan ',
#  ' biztos gyerek ',
#  ' biztos család ',
#  ' fijam hol vakcina furcsa hamar elen szer ',
#  ' penicillin érzékenység ',
#  ' cintia volentér magyar kéz állami tulajdon ugy fidesz ',
#  ' andrea bakonyi idős gyerek otthon biztonságos környezet ellenállás közösség bölcsőde óvoda iskola jelen_eset asztmás szívbeteg allergiás gyerek kis kockázat oltás valamikor gyermekkor influenzás sosem idén influenza járványkórház covi fertőzött ismert két vírus találkozás következmény durva ismert ápoló halál végződő mrsa covi kombója gyereked biztonság sajnos kiemelt veszélyeztetett ',
#  ' sándor horváth sajnos világszerte olasz tévé újság vírus állítólag együtt ameddig védőoltás orbán ',
#  ' andrás kiss rendezvény megtartva jelenlegi korlátozás erez korlátozó intézkedés kórházi férőhely függvény súlyos_beteg addig védőoltás otthon ',
#  ' árpád vass kevesen immunis továbbra korlátozás szint kórház súlyos_beteg rendezvény védőoltás ',
#  ' mesterséges kirobbantott vírus pénz cég oltóanyag plusz kína kellemetlen ',
#  ' kérdés járvány kezdet vég emberiség zöm tömött sor önként oltás előhozak paradigmaváltás emberiség további élet fejlődési irány rendszer vélemény ',
#  ' kovácsné erzsébet bcg oltas ujszulott iskolas kor ban elert gyakorlati n beteg ',
#  ' okostojás ',
#  ' jelentés anyakönyvi kivonat oltási_könyv alap állampolgár védett hányan unokahugi svédország oltás szokás gyógyszer oltóanyag ellátás raktárkészlet ellenőrzes folyamatos biztosìtás kismama kisbaba rizikós kismama immunitás hiányos ',
#  ' azonfelul vakcinat utazo miljet rend perc ',
#  ' biztos gyerek gyermekkori beadat kullancs rot vack kötelező micsoda szó higiénia maszk otthon beteg orvos kórház pl baj vírus ',
#  ' digitális oktatás gyerek ',
#  ' soha gyerek itthon kísérleti ',
#  ' bölcs ov nyitva baj ov bölcsi vírus iskola ',
#  ' oltó_anyag ',
#  ' pont megint gyerekekel kicsöszve megint szem fény áldoz mért vacinát nagyokos palament szülő megint megbüntetve nemjár gyerek iskola megint szülő föleg gyerek ',
#  ' tuti ',
#  ' gyerek chipp ',
#  ' biztos gyerek ',
#  ' balázs szabó pánikoltat operatív_törzs megynyilatkozás magyar_egészségügy lehoradt állapot pánik egyébként bagatellizálás annyira káros influenz hasonlítgatás influenza_védőoltás korona níncs influenza halálozási_ráta koronavíru ',
#  ' éva csikós bali igy igaz ',
#  ' dőglesz ',
#  ' szer főleg adag természetes ',
#  ' vakcina előállítas év ',
#  ' pènztt csinnálya ebböl szegèny csalládos mèg anni ',
#  ' tuti egyszer ',
#  ' először orbán teszteljèk család ',
#  ' edit nix kanyaróvírus ország sokan beadás amint oltás gyönyörű esetszám egyszer mutáció oltásellenesség kanyaró ',
#  ' edit nix valóban kanyaróvírus kornavírus véletlenül szokás oltás vírus vírus vonatkoztatva állítás koronavírus közönséges náthavírus gyors mutálód adat rendelkezés koronavírus információ rendelkezés jóval kevésbé közönséges nátha koronavírus ',
#  ' zsuzsanna szalai sor két kisgyermek soha mz influenza_elleni védőoltás várandós nagyobbik szervezet erős baj ember na ',
#  ' tömeges oltas ',
#  ' kubik petra erő influenza_elleni védőoltás hely sajnos ',
#  ' móró tibor bcg_oltás éves kor védelem ',
#  ' gondolom víz kis vodka vakcina kamu ',
#  ' lennének ',
#  ' cintia volentér teny amerikai tulajdon részben ',
#  ' cintia volentér magyar amerikai tv társasag ',
#  ' lemez unalmas ',
#  ' koszi kerek belole ',
#  ' andrea bordács influenzázás év két végig betegszám járvány eröltesd emlékezet heti kétezer megbetegedés hol amúgy influenz oltás mégis emberiség covi ráadás kevésbé fertőző ember megtalálható influenza covid szervezet könnyű immunerősítés fertőtlenítő sima kézmosás ',
#  ' anica horvathne főleg nyomon vizsgálat keret agy ',
#  ' ágota szabó belügyes ',
#  ' ágota szabó amúgy szép nap ',
#  ' ildikó békefi ',
#  ' bebizonyított baj felnőttkor hatás éves kor magyarország kötelező_oltás ',
#  ' kubik petra tbc oltás ',
#  ' megyeri gábor oltas pozitiv akor tév igy nekikel nép nyolcvan százalék ircsák mid hir pletyka alap tudós miben isten szabad_akarat ember döncsön élet föl élet szabad_akarat hit ',
#  ' ár sokáig vírus hatás gyártás sebesség hozzajutas lehetőség távlati terv ',
#  ' több koronavírus komplikáció ',
#  ' ismerős nyugdíjas orvos komoly szívprobléma magnézium szép dolog fenti példa épp bibi esély kivétel szabály ',
#  ' urhegyi andrea kicsi ',
#  ' judith erdekelne koronat ink mutet december varo mire veg egeszsegkarosodas szo ont dolog en eletminoseg exponencialis ',
#  ' szep nm koronas dogolj otthon ',
#  ' zsófi ladányi rend olaszországi spanyol hasonló szerencsére szörnyű helyzet ',
#  ' helyzet ember családtag akut sebészeti probléma teljes üres sebészet rendelés azonnal nyilván baj hol new york parok ',
#  ' urhegyi andrea végül ',
#  ' kinga petri javasasszony füvesember jah borbély ',
#  ' márta borosjenői lomb lombik kezelés sehol mag lombik klinika nyitva ',
#  ' év tulterhelés fogorvos duma sürgős huzz ',
#  ' tapsikolj továbbra hülye pánikbeteg baj sokan vírus helyett ra stb kellemes betegség ',
#  ' andras gergely rendeltetésszerű adó ugyebár lassú sor bak ',
#  ' bara csaba máshol miként normál körülmény időpontos rendszer fogfájós sosem időpont hét állami fogászat eset igaz ahány ház szokás ',
#  ' máthé balázs rendes t probléma világ ',
#  ' beatrix szabó magánklinika fogfájós pénz se időpont év páciens ',
#  ' marika gludovátz pontos sajnos vigyazz orvos maszk kesztyű beteg szerencsés tényleg dolog otthon élet veszélyeztető betegség jelenleg ',
#  ' igaz beteg kuss név ',
#  ' csilla némethné szakács korai ',
#  ' marika gludovátz orvos köpeny csoda telefon hajlandó beteg ',
#  ' terhes rákos ',
#  ' szemrédi erika komplett műtős öltözet ft tavaly sima császár apa ',
#  ' természetes veleszületett akut betegség baleset egészség törődés szűrővizsgálat életmódbeli kontroll vizsgálat online önkéntes természetes ingyen tanács orvos kisgyerekes anyuka életkor munka ',
#  ' tóth katalin természetes szer ',
#  ' nyilván vírus élet közel lehet helyzet hónapos pocaklakó kitartás ',
#  ' zsófi ladányi jogos kérdés ',
#  ' györgy válomos maszatol dicső vezír első eset maszatolás vegytiszta gátlástalan hazugság ',
#  ' koronavírus otthon sima hétköznap lazán ügyelet ',
#  ' fogászati ügyelet szombathely húzás kezelés ',
#  ' sote nek ',
#  ' kérdés helyzet terhes pl épp újszülött koronás érdemes ',
#  ' józsef ács egészségügy hülyegyerek ',
#  ' kegyetlen járvány ',
#  ' ferenc mayer gyermek ',
#  ' meredek megoldási körüli betegsz ',
#  ' ágnes kertész kormanyzati kommunikacio valosag kozott max atfedes hivatalos esetsz jelenleg koz ko nulla egeszsegugyi ellatas mikoz egeszsegugyi szakember ',
#  ' hazugsag ',
#  ' anita papp halapenz ',
#  ' v ramo pontos sajnos ujdonsàg ',
#  ' hazugság lételemü ',
#  ' tapsoljat ',
#  ' kevesebb ezer beteg rész kórházi ápolás mégis egészségügyi_rendszer ',
#  ' taktika váltó index réteg lázitani aljasság határ ',
#  ' apás szülés békeidő védőfelszerelés ',
#  ' ferenc pausits igaz aljasság százezrek élet járványüzemmódba kapcsolt egészségügy ',
#  ' szerbia észak macedónianak maszk vedofelszereles itthon apuka szules dolog csodálatos ',
#  ' ferenc pausits igazság lázítás biztos rend borkai párt alapelv uralkodj ',
#  ' márta borosjenői ',
#  ' tegnap elhunyt ember koronavírus pánikol érdekes tegnap hányan ellátás hiány álszent ',
#  ' legal veszely emberelet ker ember norm ido alap ellatas ',
#  ' milliárd magyarországi határ_túli stadion sporttámogatás összeg fél orvos nővér könnyű ellátás ',
#  ' ferenc mayer elegge destruktiv velemeny remelem es gyerek raadasul panik kozelit bun kategoria ',
#  ' kiss imola mantra next ',
#  ' szakrendelő üres ezer szánalmas ',
#  ' józsef ács balos ujsagtol varj tobb ',
#  ' járulékos veszteség vírus szám igaz ',
#  ' gyökérkezelés fog fogkövemet gyulladva fog gyökérkezelés ',
#  ' linda réti igazsag nyilvanoss sokan ',
#  ' anita papp kórház ',
#  ' máshogy fog órási rizikó ',
#  ' korhazat letiltani hulyeseg ket korhaz kijelolv fertozott tobbi hasznaljú beteg ugye korona ',
#  ' sziráki gyula tanulj agitalj ',
#  ' terhes honap ',
#  ' sose ',
#  ' rég európa tönkretétel ',
#  ' tulvan bonyolítva vírus körüli hisztéria miközben megbetegedés vírus tény ország nyomor taszító tilalom immunitást vírus ember vírus orvos tudomány vakcina vírus vírus_terjedés késleltetö intézkedés vajon értelem ',
#  ' tamás skerhák hol orvos nővér év felettieket kivonták eü dolgozók nagyrésze nyögdíjas ',
#  ' zoltán valcsák gyerekszemész magánrendelés beláthatatlan ',
#  ' hamar nyilván máshol xar regisztrált eset ugye ',
#  ' hol óra biztos magyarország időpont magánklinika ',
#  ' gabriella zahoran valahogy hátre eset rák kezelés intézményrendszer hatékonyság várólista ',
#  ' fekete edit március elő vizsgálat szükség sebészeti mammográfiás egyik szó ragály kórboncn baj egyedül tömegek ellátás igaz kórház jócskán ürülve mindjárt szív orvos túlterheltség ',
#  ' bejuttatási procedúra ab kevés kraft ',
#  ' érintett kemoterápia mara múlt hét kezelés ',
#  ' ágnes marjai ugye magánrendelés húzás engedélyezett fogtömés gyökérkezelés semmily eset semmily forma hónap fájdalomcsillapító ',
#  ' gabriella zahoran hol hét időpont időpontkérés óra ',
#  ' antónia oraveczné kovács ja orvos nehogy wtf ',
#  ' nyilván fog ',
#  ' zsófi ladányi kíváncsi közel lévő kórház üres daganatos beteg ',
#  ' miklósné hankóczki megértem düh ',
#  ' ágnes marjai húzás ',
#  ' ferenc pausits ',
#  ' richard dawkins posztol megelőzés fontos középkor emberiség százalék ',
#  ' ember kor vírus egészségügyi ellátatlanság ',
#  ' káosz elmúlt_év teljes lezüllesztett magyar_egészségügy forrás járvány eredmény ',
#  ' nora keri nál sima szülés védő szett lábzsák maszk köpeny sapka f bent férj szülőszoba sima szülés kórház ',
#  ' alexandra schlick vicc hely szemész beláthatatlan idő ',
#  ' kisuczky attila idióta amúgy tényleg idegesítő helyzet ',
#  ' alexandra schlick agyaltam kiirj aztan címezv gyors ',
#  ' zsuzsa harazinne egészségügy kb asztrotv műsor telefon gyógyító energia ',
#  ' orvos helyzet youtu akadémia ',
#  ' húg intenzív pelenka törlőkendő szülészet ',
#  ' mémégsem eü hol világszínvonalú ellátás ',
#  ' se beteg szemészeti vizsgálat fél_év várakozási idő urológia hónap ',
#  ' oltás fesztivál igazán nagyban köteező oltás chip különben hnnan ',
#  ' szabadnap ',
#  ' baszd autistává oltott gyerek ',
#  ' laco white totàlis kontroll sokan mondjàk vilàg kormàny kialakuló vège drmokràcià ès szabadsàg ezèrt g oltàs beadott nanorobot tudjàk genetikàt bio robot ember g egèszsègromboló megbetegedés ràfogjàk covi ezutà rövid közeli jövőkèp utàna ',
#  ' ágota szabó g rák stb ugye ',
#  ' anica horvathne bocs ',
#  ' dédanya újság kéz valószinűleg dolog ',
#  ' vida viktor csaba népességcsökkentés cél többi hazugság ',
#  ' föl tupírozva járvány elegendő örég beteg immunrendszer természetes út orcavédő megfelelő alkalom művi oltás jobb ',
#  ' sándor erdei ',
#  ' dinnyési gyula rész mérnök ember egyáltalán elektronika cég kifejezett iot hardwér fejlesztés ilyesmi ',
#  ' márta bacsó igy felelelkeltes ',
#  ' előre betegség koronavirus ',
#  ' katalin bódi idefigyelj tilos antibiotikum állítólagos korona vírusos beteg tv bcg_oltás ismétlés veszélyes hely egészségügyis bcg_oltás gümőkór vírus baktérium baktérium antibiotikum protokoll olasz who előírás baktérium elhunytak vírus hol igazság ',
#  ' rab káosz hülye radikális rács kint ',
#  ' sehol se ellenszer ezáltal se megelőzés vakcina ',
#  ' bájos párbeszéd ',
#  ' kun attila egyértelmű mesterséges népesség szabályozás szó ',
#  ' sipos lászló màrmint libsi horda egységes sötét massza kedves làszló ',
#  ' kis háborús buli jobb ',
#  ' gábor hunyadi szeret kis harmadik vilàgháború gondoljodni ',
#  ' fényes györgy màr vilàghàború libernyàk hordà spàjz ',
#  ' molnár attila hiteltérdemlő ellenőrizhető bizonyíték korona_vírus hely virológus megfelelő orvosi diploma hozzájutottál hadd vírus ',
#  ' tamás imre stabilitási alap vakcina ',
#  ' ákos autò ',
#  ' bea ághová mire gondoll en januari influenza jarvany remel oltas ellenszer valo ',
#  ' gréta galóca víta dolog jobb csend éves íly oltás ',
#  ' hülye duma aktív passzív vírus szájmaszk ráv írva fertőzés vírus védekezés öreg reggel tól ig fiatal bolt vírus nap életképes pl műanyagfelület vírus melegvizes szappanos kézmosás oltóanyag hová gyógyszertár orosz ban kifejlesztett gyógyszer ban hatékony kezelés ',
#  ' biztosítsa kormánx ingyenes tesztelést kötelező ingyenes tesztelés magyar_állampolgár járványügyi érdek jelenleg hatályos egészségügy szóló törvény kormány mégis tesztelés védőoltás biztosítás ',
#  ' anica horvathne világ chip oltás ',
#  ' ágota szabó kb ',
#  ' veszélyesebb influenza _év visszatérő járvány karantén oltás vírus ',
#  ' ágota szabó észt kizárólag ',
#  ' anica horvathne érdekes közeg ',
#  ' érdekes világ internet infót keresztény ',
#  ' sándor erdei mérnök ',
#  ' peter verhas koszon piszkalodas autodidakta cég profil ',
#  ' covid influenza ',
#  ' kasler ut mengele kórházürités kisérleti kötelező_védőoltás teljesi ',
#  ' ellentmondás kamu qrva kamu ',
#  ' furcsa védelem baj ordenáré alak önelégült magabiztos oltóanyag biztos gyanús eset pint hét magabiztos karantén vaj mi magabiztos önelégült igazából kíváncsi ',
#  ' es eredeti ',
#  ' lamp attila igaza emberi butasag kor hatartalan saj hitvallas bizonyiték ',
#  ' vígh gábor eszetlen aids oltás vìrus ember ütődött gyógymód darázsméreg terápia alkotó reakció szervezet mellékhatás hisztaminfelszabadulás ',
#  ' spátay györgyi igaz kötelező ',
#  ' főorvos csodálatos nap dolgozó ',
#  ' gábor bencsics halálozás függvény pár halálossabb influenza felesleges influenza aszimptomatikusan túlzott fertőzés tünetmentes olcsó gyorstesz pontos nyál antigén munkábamenet kb eltüntethető járvány bármily lezárás vakcina ',
#  ' mónika dénesdy kiritkitanni emberiség állam ',
#  ' miénk közpénz eladják enye ',
#  ' kétség igaz statisztika szerinte kötelező bcg_oltás eredmény véletlen nagy veszély továbbra ',
#  ' bcg_oltás ',
#  ' bcg_oltás egyedül magyarország kötelezo sehol máshol magyar védve kötelező sehol ország oltás beteg idős_korosztály veszély ország innen onnan ',
#  ' szerinte fertotlenitos oltas ',
#  ' szerbiai média szőkeség arany mondat felvesz vakcina maszka kesztyű távolság tartás szülő kozepsuli tanár alig levegő beszéd köz gyerek maszk óra két csoportos oktatás hülyeség vég szülő hisztizet portás fertőtleniteni takarító arc nagymamám korabeli kendő kéz fl törlőkendő tragikomédia ',
#  ' rövid_idő oltòanyag mellèkhatàs mèg ràadàs jò dràgà ',
#  ' eva helena kuluncic ',
#  ' lászló tóth agy sötét ember világ borzalom vírus megoli ember ',
#  ' emese tóth tapló paraszt agymosott halott ',
#  ' tunde soos sajnos kezdet durv név hadmuvelet id ',
#  ' népesség ',
#  ' boda tündi könyv gyerek hol ',
#  ' éva maller pontos igazi család ',
#  ' boda tündi szájjal faszerdő ',
#  ' makár papp katalin teljess különböző boldog közben tudatos döntés boldog élet tessék semmi élet mié boldog élet ország fél ',
#  ' makár papp katalin szomszéd korlátoltság ',
#  ' súly téma telt nő képes teher rokono gyerek telt idomok black egyébként kövér kövér ember oldal tag ',
#  ' boda tündi barát könyv menny szűni csok ',
#  ' klára zavar lélek csesztess nő gyerek ',
#  ' adria szappanos szempont lényeg ugyan ',
#  ' ééés borsos remekmű szavalni ',
#  ' kerek ',
#  ' tudományos bizonyítható ',
#  ' nak járványügyi bizottság egészségügyi_rendszer donorlista szaporodás képes többi oltási_könyv ',
#  ' éva keller magyarország ',
#  ' vírust influenz jogtulajdonos g hamar budapest kína természetes g továbbra veszélyesebb aktuális működő gsm szabvány ',
#  ' oltóanyag baj szarer tele teste valami amúgy se sor hülye következmény ',
#  ' baj felesleg magyar dolgozó megélhetőség pénz külföld ajándék ',
#  ' bárkányi lászló ',
#  ' fer ész beszéd pénzböl kap nobel_díj ',
#  ' hernádi mária három felkiáltójel mögé kis ökörség tudtad ',
#  ' márk dabronci egyedül ökörség összes felkiáltójel ',
#  ' hazudozás ember becsapás hülyítés ',
#  ' gondolom oldal letöltés szám drasztikus csökkenés komoly veszély rémhírkeltő média ',
#  ' böröczkyné lékai szilvia ',
#  ' eőri zsuzsanna elegendő maszk ország halom haver megszedjék ',
#  ' lélek szaros vírus ',
#  ' nika csilla okos poszt jakab válasz járvány megtagadó szám okos ',
#  ' gergely horváth degradálsz ',
#  ' sanofi oltóanyag eb szeptember klinikai_vizsgálat oxfordi egyetem vakcina fázisú vizsgálat brazília ',
#  ' iván félix pontos németország tesztelés álló oltóanyag igaz sanofi sanofi lobbitevékenység háttér ',
#  ' angelika thurner ',
#  ' enis madárinfluenza sokan pánikbol szar védőoltás paran mai nap vakság rák es hasonló finomság kár pánikbol hulyeség ',
#  ' tibor kósa magyar házipatika nevű oldal mayo clinic variánsa ismert jelezve variáns védőoltás ellenszer törzs sertés ',
#  ' oltassa év egészségi állapota beadat népbutító barmok ',
#  ' tuti ',
#  ' bernad füles jogos utobbi ido amugy teny kukaba egesz sim okfejtes hazugsag ',
#  ' adassa hét anya ',
#  ' tiltakozó három ',
#  ' rózsa nagyné danka ország világ ellenőr jelenlét hatóanyag ',
#  ' miklós istván kötelező_védőoltás valószínű oltás év egészségügy máris ember laikus oltásellenes ',
#  ' miklós istván lap tartoznaknaz influenza korona_vírus ',
#  ' edit nix politikai oldalú politikai oldalú lap lapszemle mindkettőben ',
#  ' év megint igazság gyerek sztatisztika bármilyent sosem valóságtartalom tapasztalat azbélet bizonyos életkor szint élet vég sokszor tényleg ji irányítva ',
#  ' biztos nemad majom ',
#  ' fél_év rádió hawaii város szülő fél oltásellenes tiltakozás elis érték céluk kis idő hónappa malária fős vásor gyerek congratulations ',
#  ' orvos vakcina_kifejlesztés év gyors összedob belegy adva ember mindenhova szar orosz csodálatos cucc orvos elmondás kár vírus személy lehetőség orvosi véleményezés álláspont ',
#  ' rémai viktor franc erdekli elegen ',
#  ' hátul ',
#  ' biztos ',
#  ' jukka attilai agresszív szuri nadrág vírus egyes fej ',
#  ' csalad kiserletez ',
#  ' erzsébet szilágyi borzasztó augusztus i határidő mennyi pénz utópia ',
#  ' vakcina duplán gyarapodhat gyógyszergyár vagyon ',
#  ' tibor aggódj g kontra oltás sztori ',
#  ' mária tamás vírus influenza krónikus_beteg szövödmény örökre vakcina beoltat ember maszk év ',
#  ' gábor lovácsi oltás fényév jövő tavasz elérhető addigra sokmillió ember addigra járvány komoly sírva oltásért sor oltás reális kép kockázati csoport oltás év megszelidülhetne nátha szint kötelező ',
#  ' plusz influenz elvileg megelőző oltás malária gyógyszer rák cseppfertőzés öngyilkosság dohányzás alkoholfogyasztás abortusz egyéni döntés korrekt halálozási szám összehasonlító lista feltüntetve mintegy bagatellizálva szám ',
#  ' veronika máthé nagyhatalom hozzä baromsäog järväny addig amig biztos oltoanyag védekezés maszk kesztyü tävoltartäs tompitani ',
#  ' iren heinzl örökre infulenza hal idős_korosztály infulenza oltóanyag sokan ',
#  ' zsanett kovács kötve ezelől év turizmus szórakoztatóipar sportközpont százezrek ágazat tartós kinyír durva következmény hatás egészségügy millió fertőzött rendszer papír max halott generálna tartható lokális korlátozás menedzselhető járvány innentől egyéni felelősség idős_otthon társadalom kollektív áldozat vakcina kötelező év ',
#  ' összeesküvéselmélet egyszerű ember védőoltás agy képtelen bizonytalanság ismeretlen helyzet nagyfokú szorongás ember konteóhívő egyszerű kész válasz szorongácsökkentő drog bizonytalanság rideg valóság től független természeti erő igazán kormány bizonytalanság jövő illető hiszti agy sima végelesz soros g torny ',
#  ' valószínűleg idős_ember idős_beteg gólyabál balgaság idős veszély eset fiatal fertőzött súlyos tüdő agyi szív károsodás ',
#  ' gergő lengyel ugye nap lappangási idő egyébként genotípus annyira különböző vírus hasonlítgatás főleg influenzáz különböző genotípus különböző viselkedés viselkedés elképzelhetető covidon különböző influenza calici eset ',
#  ' szokásos hétvégi buli kissé arrafelé normális ',
#  ' hónap ',
#  ' zsanett kovács stratégia valóban mögötte első korrekt idő bátran járvány együtt hosszú_táv minimum halottszám svéd vakcina round gazdaság vég megoldás lefékezz influenza _év ',
#  ' papp lászló szigorú feltétel megfelelő távolság védekezés csoportosulás felnőtt ember_élet ember vég ezután mostmár felkészült mégis rossz_helyzet tulajdonképpen nyálimmunitás ellenszer védő_oltás év vírus soku nyilván védett korú idült beteg ezután ',
#  ' anikó vidóczi feltétlen tünetmentes igg hét vakcina betegség megfelelő szekvencia szervezet megfelelő adjuváns vakcina ellenanyagtermelés bő megfelelő erős tüntetmentes ',
#  ' ész fehérítő virus ',
#  ' veszeli at fiatal ',
#  ' ferenc barna ember ',
#  ' elő talaj biznisz milliárdszám drága pénz oltóanyag nevezett cucc ember zseb pénz lakosság ellesz hit szép csend egyszer emg ',
#  ' maszk oltás tagadó helyes főleg járvány környező_ország ',
#  ' röhögőgörcsöm cikk ',
#  ' piocs ',
#  ' vírus korábbi év ember nagy influenza natha járvány tömeges megbetegedés háziorvos alig szájmaszk pl busz betegen eldugult orr köhögős hol odafigyelés szájmaszk fertőzz ',
#  ' sándorné herceg hülyeség db kenyér jobb len ',
#  ' erdei ferenc ketto ',
#  ' tünde kohajda hülyeség hergelj felesleges ',
#  ' márk dabronci mióta immunrendszered szoktatás természetes védekezés szűrés ',
#  ' ferencné farkas inteligens vírus ugye vírus ilyen ',
#  ' anyát nèzzètek vègkèpp segg kar basszadszájbakurvanyád ',
#  ' gyeri laposföld hívő ez jobb összeesküvés konteó véglet elkoptatott fixa ideáit mantrázzát vég rettenetes irritáló végre ',
#  ' márk dabronci szabad rég védve esetleg oltva virgonc ',
#  ' györgy jánoskovics durva ',
#  ' márk dabronci nyilván évtizedes ismertség ',
#  ' károly szabadkai vakcina ',
#  ' kovács lászló cili_néni felesleges elő pont ellenkező ',
#  ' szilárd schmidt igaz helyzet ',
#  ' reméle pénz érdemes vakcina_teszt ',
#  ' szerinte védőoltás drága ',
#  ' eva kelemen adhasa ',
#  ' játék gyógyszer vakcina f ra debil ',
#  ' hajrá nagyfejűk haszon tuti oltat ',
#  ' baba párt mélyen erős szektás védőnő tanács lelki védőoltások régen természet terhesség kettő élet ritka család betegség mai orvostudomány védőoltás korda jobb baba szerető család mégha család szegény vég oviba suliba se barát szekta esély rendes élet mégha pici törés ',
#  ' halálos_vírus gyógyszer x beteg szappan fertőtlenítő hártya maszk pontos vírus gyors védőoltás vajon mire ',
#  ' mas ',
#  ' barbi hervay ',
#  ' éhínség ember pánik keltés ',
#  ' imre cserép fontos kötelező kötelező egyszer szerencse tényleg összefüggés este bonyolult dolog épp veszélyeztett korosztály oltva kötelező_oltás éves kor alatti oltva elérhető ',
#  ' igaz bizonyos vakcinagyár termék hol hol bizonyos bevétel bevétel kérdés ',
#  ' hajcser andrea meglátás konkrét oltóanyag se szövődmény influenza se teljes vírus agresszív sajnos ',
#  ' politikus média munkatárs segg ',
#  ' sunyi orv csakhát ',
#  ' dániel baksa ',
#  ' ismerős éves oltás ',
#  ' elmélet ',
#  ' rasszizmus ',
#  ' szilágyi károly lakosság immunitás oltóanyag elkészülte beadás ',
#  ' klinika teszt influenza klinikai_teszt rész szívesen ',
#  ' marián pálfi rohadja ',
#  ' ernes bio oltás ember barát brit tudós megállapitotta ',
#  ' eva kelemen pontos ',
#  ' ernes szájmaszk nö bugy nap honap használt bugyi kibir orr pont illatos maszk haj ',
#  ' adag franciak ',
#  ' mónika dénesdi cikk s általánosság olvasás gondolkodás ',
#  ' petra réz influenza eves szint ezer ember halalat koronavirus tavaly ev veg kina mar ezer folott halott szam vilagszint mirol influenza_oltas felulfertozodes eredmenyeken kialakulo tudogyulladas antibiotikum oltas antibiotikum ertelmes ember beszarva kepes nehany apro lepes elovigyazatossag jegye nehogy huly ember ',
#  ' gábor hunyadi hol ',
#  ' többi baro ',
#  ' kíváncsi húsvét ',
#  ' addig cirkusz ',
#  ' élet vég otthon pentag terv ',
#  ' szilard dredan screenshotold valaszod kuldd hiphop tavasz veg belole ',
#  ' nyafog libsi horda nemzet ',
#  ' páll gyöngyi szó igy ',
#  ' embertárs védelem érdek ',
#  ' tessék semjén zsolti pannonhalmi bencés megnyitó maszk ',
#  ' virus kis gazdasági válliság ráfogni milliárdos pénzkereset ',
#  ' krisztián kovács kire veszélyes ',
#  ' tomasova ruzenka who bill_gates oltóanyag népesség csökkenés oltóanyag hosszú tàvon későn hatàs mód magàt ',
#  ' stadionok fertöz vírus ',
#  ' gábor gyönyörű ',
#  ' agymosott ',
#  ' komoly tavasz ',
#  ' pfúj elég eltünhet vííííroologoosúúúr ',
#  ' ft ',
#  ' szlovakia ingyenes egesz europa orbania ',
#  ' tények korona_vírus ember név koronavírus tények ',
#  ' amig ellenszer addig bcg_oltás állítólag magyarország delagil nevű gyógyszer patika ',
#  ' tomasova ruzenka vho tőlle oltås kötelezővė fiatalság körė tovåbbszaporodås korai halålozås elvetemült bill gatesz sokan bolygô felsőbb tīzezer milliårdos ',
#  ' feketék fehéreknem ',
#  ' tomasova ruzenka oltàs bill_gates gyàrtva előre vîrus megjelenés félelem vilàg nép oltóanyag biztos súlyos mellékhatàs màr gyógyszer ',
#  ' térkép szocialista ország kötelezővol bcg_oltás látható beteg haláleset németország látható keleti oldal berlin főváros kivéve jóval alacsony fertőzöttség szerintem mintás kísérlet ',
#  ' zita orosz igaz jelenleg járóbetegellátás rendes krónikus_beteg vírus világ rész terjedés hozzászóló alkalom álláspont november tájék oltóanyag ',
#  ' béla zoltán hegyeshalmi jóval glattfelder török későbbi naponta lakosság tesztelés fél_év gyakoriság duplázódási ráta pontosság javaslatuk szűrés izoláció határ további szűrés kizárható járvány újbóli kitörés módszer belső forrás történő újbóli járvány tömeges szűrés azonnal elhagyható amint elérhető gyógyszer vakcina javasoltnál hatékony személy szóló gyorsteszt ',
#  ' gyerkkor mire szervezet ',
#  ' egyszerű fertőzés oltás immunrendszer semmily specifikus hatás valószínűleg drága ',
#  ' himlo oltas hely egymas nek ',
#  ' alexandra gráf szandi év egyetem biztos lelkigondoozó néni azóta lelk ',
#  ' nikolett cserni szerintem ',
#  ' anyjuk mire halálos_áldozat normálisak ',
#  ' ès csalàd biztos ',
#  ' gergő lengyel szeretnè magàt egèszègè ès csalàd biztos fogjàk kedves hölgy tudos tanai magdi là szem fül tele kutat orvos vèdöoltàs normàlis kifejleszèsè minimum felfejlödt mostmàr gyors vicces kicsi bàr hozzà adjàk ',
#  ' gergő lengyel kedvessègèt kivàn jòt magà ',
#  ' ilona kiss sajnos okos képzett adat szívesen addig infói pletyka szint ',
#  ' nekünk bátor emberünk parlamentben kiváló kisérleti anyag hajrá_magyarország ',
#  ' edit nix ööö himlő járványos gyermekbénulás kanyaró vírus betegség oltás visszaszorított sikeres kanyaró nehéz okos oltásellenes rendesen ',
#  ' egyszer sohaaaaa ',
#  ' alap ',
#  ' miklós istván sajnis ',
#  ' naponta ',
#  ' biztos elsőtöl második végzetes ügyes biztos ',
#  ' rabló magyarország kétszeres ár ',
#  ' főorvos kg narancs ',
#  ' alap védőoltás genotípus kiindulási pont többi viselkedés influenza_védőoltás ',
#  ' sándor varga nyilvàn kormànyzatè rogán antal bcg_oltás tök rég ',
#  ' zsuzsanna virág oltás covi biztos ',
#  ' korrekt tájékoztatás ',
#  ' vakcina emgiráns zsidó merkel német állampolgár ',
#  ' év vakcina ',
#  ' év oltás ',
#  ' hány év élet ember többség tényleg vakcina év feletti ',
#  ' addig rendkívüli felhatalmazás remélem ősz oltóanyag ',
#  ' szakember védőoltás ellenes biztos enyhe lefolyás koronavírus fölösleges feltételezések bizonyíték ',
#  ' tóth andrea baj nyilván addig elõvezetni biztonságosság pont hamar oltás ',
#  ' immunrendszer dolgozó véletlenül ',
#  ' krisztián házi teljes naprakész magyarország átlagéletkor átlagos élet védőoltás rendes orvosi_ellátás csecsemőhalálozás szám hetes magzat élet élet gonosz egészségügy ',
#  ' emberek halgasát ',
#  ' alexandra gráf kémiatanulmány hát sokan ec háztartás ',
#  ' anyát oltsáto köcsögök ',
#  ' ágnes rácz család ',
#  ' gergő lengyel jòkèpű ès inteligens tünő fèrfi mièrt là orr hegyè tovàbb ',
#  ' érdekes hamar szer akinek esze adatja ',
#  ' sàrosinè szabó ilona oltat influenza egyszer oltás beteg soha influenzás ',
#  ' ismerős tesztre óra várt mire levél koronás se ',
#  ' orbán_viktor ',
#  ' egyszer legbiztosabb ',
#  ' feltünt oroszország vakcina ezazzzorbán orosz világ zsarnok mennyi pénz ezz diktátor ',
#  ' naponta virus ',
#  ' budos loher virag ',
#  ' csakis bátor patkány ',
#  ' kardos ottilia ',
#  ' ember prototípus vakcina ',
#  ' na tényleg felháborító itthon komoly segítség kifel ',
#  ' fontosabb ',
#  ' hermina hegedűs ember birka maszk kötelező neves profeszor doktor többeközött német doktor szájmaszk használat káros egészség ember kormány média maszk gyerek injekció duplán biztos jövő érdek ',
#  ' ecs bánatos fasz külföld forint ',
#  ' hitel hitel hitel gazember gyülekezet mostani kúrmány nép ország város felnégyel test humanizmus ',
#  ' ģyár magyar es é songino magyar_szakember ',
#  ' maradjál végleg ',
#  ' első nemzeti kumiszgyár ',
#  ' suty összeharácsolt vagyon külföld fidesz ',
#  ' kenyeres noémi majdnem anyi külömbség influenza kezelés egyszerű köptetö gyulladács csökkentö pihenés vitamin esetleg antibiotikum bakreriális szervezet védőoltás értelmetlen korona ugyan külömbség sok tünet minimális kezelés komoly fertőzés hatékkonymódszer vérplazma vérhigító immunerősítő vitamin pihenés védőoltás pontos anyi értelmetlen influenz hameglesz téboly ',
#  ' vágyálom vakcina ',
#  ' hullám mire vég normális védőoltás vírus szappan víz sajnos se zavar tanár hiába tanár ',
#  ' kenyeres noémi vettt kezeles c_vitamin influenza pihenes alvas lazcsillapitas covi influenza sokan felesleges ',
#  ' csaba zsiga világjárvány orvos világjárvány világjárványró bolt tömegközlekedési eszköz előre közel folyékony szappanos kézmosás kis nyavajás védőoltás ',
#  ' pal pontozo hely vakcina célzott koronavírus kifejlesztett szer járvány igaz haláleset szám minimálisra betegség lefolyás időtartam tünet erősség jelentős vakcina járvány ',
#  ' barbi barby világ_járvány or jobb ',
#  ' barbi barby emlékszem g kiírt föld lapos ',
#  ' úgyis idősotthon külvilág tisztességeseb higiénikusab tömeges fertőzzék vég öreg út ',
#  ' zsuzsanna rácz merkely féle felmérés alap átfertőzöttség körüli ezer valós betegszám saccol reprezentatív felmérés mennyire pontos számú tesztelés durván ',
#  ' angelika mihalik ',
#  ' év pedagógus tanár bcg vakcina pályafutás biztos pályaelhagyó időköz ',
#  ' teréz bakos szakember baktériumölő hatás ',
#  ' erika tódor tessék biztos szár oltás ugye szerinte szar gyermék hülyeség ',
#  ' puzsér róbertre igaz szekta isten megnyilvánulás egyenlő parancsolat ige hirdetés ',
#  ' hülye brüsszel való ',
#  ' milessz magyar szarházi mocskos gyilkos tróger banda magyar kutatás támogatját mocskos kot szőkevény ',
#  ' miėrt büdös fasz mėg ember ',
#  ' rokon többi szájtáti dóg ',
#  ' marson ',
#  ' biztos magyar ',
#  ' szinák zoltán járványkórház infektologus dolog végzettség kommentelő hirtelen orvos virologus infektologus avanzsált kommentelő adat vizsgálati anyag ',
#  ' achilles gül burgonya ',
#  ' balázs szívós ó basszus élet védőoltás visszabetegszik butaság angol kínai német beszámoló agyament pánikkeltő magyar füvesember ',
#  ' gabriella kemény gondolat influenza_elleni oltás igaz ',
#  ' kucsera barnabás állítottam ellenkező tud pont oltás _év százezrek influenza ',
#  ' védő_oltás kiraly sima_influenza tel egyszer nindig korona tünet legszomjj kegyetlen testi fajdalom ',
#  ' védőoltás kialakítható nyájimmunitás kanyaró marha fertőző alig hatás ',
#  ' morong gábor védőoltás ',
#  ' dolog világ kutató_orvos oltóanyag addig baszhat okos minél annál nehéz ',
#  ' börtönpopuláción ',
#  ' vég járvány ázsia vírus halálos közlekedés áruszállítás ismételt világ használható koronavírus elleni_oltás fertőzés ellenanyag hét szervezet ',
#  ' pesszimizmus ',
#  ' ló ',
#  ' végül tudományos állítás igaz tuti ',
#  ' szerinte idő augusztus végi fesztivál megtartható amúgy akármikor jaj év vakcina addig ',
#  ' mihály millió azonnal bevethető ',
#  ' bar jobb ',
#  ' drukkolunk nektek pecsi csapat sejtem magyar ellenszer ',
#  ' vírus magyar_orvos kezelhető ',
#  ' farkas csaba influenza effektív szaporodási ráta kis plusz védőoltás csomó törzs ',
#  ' kucsera barnabás mutáció sérülékeny kemény törzs az védőoltás ',
#  ' morong gábor védőoltás vég influenza vég ',
#  ' maczkó lászló vilagjarvany oltás ',
#  ' igazán sokan év ezelőtti okfejtéseid sokan vuhani labor tied innentől ',
#  ' oltásellenes who egyébként videoajánló algoritmus ',
#  ' hatékony ország fertőzésszám nyájimmunitás száj kevés lakosság átfertőzés egyébként kétes bizonyosságú immunitás remény eddigi halálos_áldozat kétes bizonyosságú immunitás mire feltevés oltás kétes bizonyosságú immunitás annál fertőzés átesi ',
#  ' agnes tschudi biztos ',
#  ' kaiser katalin katalin úgyis igaz feltűnő miniszter maszk nagyvilág féle_vakcina hányan higgyél ember könnyű ',
#  ' dejóó mèg kötelező_oltás ',
#  ' morong gábor védőoltás rendelkező influenza ciklikus ',
#  ' cikk szukseg ',
#  ' vuhan védőoltás karantén ',
#  ' büdös ló sz ',
#  ' szol nemj jama t ',
#  ' peter mester ',
#  ' politika csöd ember mészáros orba szép lassú kötelezö bör ültet csip aztmár ember gazdasági összeomlás ',
#  ' lívia forró almási ',
#  ' hol máshol összetétel mellékhatás diabétesz japánok érdekes vég járvány ',
#  ' elmegyógyintézet hely ',
#  ' feri néni náthára rot védőoltás hol szénanátha allergia ',
#  ' influenza_oltás influenza év mutáció tobb ezres haláleset maszk karant végig gyerek majm kísérleti majo hatás nezz utana ',
#  ' startlap pont ellenkező ',
#  ' lélegeztető valójában szükséges vírus dolgozó anya anya addig ',
#  ' fos brüsszel hamarosan határzár ember talp ',
#  ' idös krónikus_beteg vírus mostanra fiatal tavasz éjjel nappal ',
#  ' kenya felépült kórház vietnám mongólia sosem ',
#  ' márta szalai itthoni állami beruházás ügy illetékes egyéni vállalkozó felcsúti kisiparos ',
#  ' itthon mire nagy rend ',
#  ' állás ',
#  ' ország bárhonnan egy vég ',
#  ' róbert révész buta kerdes valasz ',
#  ' véletlen itthon következő kormány külföld vagyon fideszes gőz ',
#  ' éva juhászné vass baj sok minimum_év irany fidesz borzalmas politikai analfabéta fidesz_szavazó rész vitya tegnap baj ártana visszanezni korán ',
#  ' vezér barom rész maszok eljotékonykodta ',
#  ' ellenzék fotelekbol utca tetves maffiat sose levaltani rendszer iramyitasuk ',
#  ' romànok ',
#  ' ház fiú kis zsé ',
#  ' mért ithon ',
#  ' veg jo hir mar aggodas fog mongolia itthon epiteni ',
#  ' felsorol orszag ',
#  ' mongólia munka magyar hihetetlen kormány magyar egyedül ',
#  ' mosoda ',
#  ' mongólia ',
#  ' elek mekk következő oltás ',
#  ' csup ellenőrízhetetlen térség kicsi gyanús ',
#  ' magyarország munkahely kiemelt közmunkaprogram ',
#  ' mèg mongol ',
#  ' nevetséges csaló fidesz ',
#  ' fullos biznisz ',
#  ' igazi hazafias cselekedet nagy szükség krízis idő idióta kormány tényleg ész ',
#  ' itthon ',
#  ' piacgazdaság mí cinikus jurta letelepedésí kötvény arrol kuss tök tele keleti nyítás arab kí kurva vég ',
#  ' zoltán kecskés maximum jurta ezerért többi pénztáros esetleg birkakergető berúgat papír ',
#  ' miklós liktor igy igaz ',
#  ' szükség ',
#  ' kamu beruházás hivatalos ország pénz soha vietnám kórház magyar_kormány milliárd ',
#  ' király gyula esetleg itthon ',
#  ' influenza beadott vakcina oltás ráadás korona_vírus fertőző megbetegítő képesség jelenség vírus interferencia erősítő hatás eredeti közlemény vaccine szakfolyóirat ',
#  ' jarvany soha erh veg ',
#  ' itthon ',
#  ' itthon milliárd ellopva ',
#  ' mért ',
#  ' itthon munkahely ',
#  ' vég teljes cimû televiziòs showmûsor ',
#  ' u i jótett jó szemelött ',
#  ' itthon pénz kutatás ráadás mongólia fejlett állam pont itthon ezer ember hónap ezer forint támogatás itthon ',
#  ' maszk kormany reszerol munkahely maganszektor promotaljú bar magyar sinc egyedulma ',
#  ' tibor galicz esély ',
#  ' fiú igazából tőrként villany oltás őrülj élet messze klinikai halál állapota ',
#  ' milliárdos elvonás egyeteem aktuális spórolási ',
#  ' kérdés ',
#  ' valóban megoldàs kilèpni orszàog uniò korrupt tűnő kormàny ',
#  ' itthon mire pénzg külföld ',
#  ' magyarország ',
#  ' itthon ló munka elmehet bús ba ',
#  ' magdolna lakatos biztos alkalmas felugyel ',
#  ' endre szeles év torten ',
#  ' szép forintocskáink nép egyáltalán nép ló korán eu pénz járvány mongólia vakcinagyár mégis kis zseton ',
#  ' gazdasági szakember magyarország haszon ',
#  ' ó töredék gyerek semmily eszköz otthon rendelkezés digitális oktatás igénybevétel feltétel jobb stadion ',
#  ' csarmasz lászló gyujtsál lámpa szénanátha allergia fél nátha nyugodt kerdezz influenza alap_betegség fertöz natha lényeg eddigi védöoltás covi tul fiatal rossz ',
#  ' sebes gábor járvány egyrészt gyógyszergyár lobbi tesó doki március első elhalálozott első ismerős belgyógyászati klinika év csont asztmás roham rend immunrendszer kór távolság adieu ',
#  ' barbi barby fincsi tetszett lupa tó ',
#  ' györgy schill ember föld ismerösei ugye sorolhatnám továb virus találva ',
#  ' valahol pénz ',
#  ' ferenc holy hű oltás kelessz buzi ló kolbi ',
#  ' kiss csilla jobb gyerek difteria torokgyik szamarkohoges kanyaro jarvanyos gyermekbenulas nyomorodna ujbol morbus hungaricus tbc oltasellenes atoltottsag csokkentese jog gyerek sajat lakatlan sziget esetleg jog ',
#  ' kezdjé tudos oltas szerény kis csaladjuk probaken annyia ',
#  ' hpv elleni_oltás mára behívó éves kislány szülő gelléri julianna oltás túlszaporodás kifejlesztv ',
#  ' judit papp on jo egeszség kivan siker tovabbi orvosi munkaja ',
#  ' szabó éva debilség szégy jobb egészséged agyatlan ',
#  ' nemzet elérhető polgár lásd teszt ',
#  ' népirtás nàci népirtás gáz genetikai eröszak keverdn szines csöcselék covid_oltás magtalanitja fehér férfi nigger elsö aljasság politika ',
#  ' ég ház oltás szükség tűzjelzőkészülék áfacsökkentés ',
#  ' eszter egyszer hozzászólás oltásellenes bizonyos oltás felesleges ',
#  ' tibor iványi reális táblázat korosztály életkörülmény főleg higiénia szempont józan ész reális valóság ',
#  ' éva ivány igazi gondolkodás ',
#  ' oltás veszélytelen ',
#  ' istene koment oltassa család pont kezdv természetes szelekció amerikai szülő sor gyerek ',
#  ' gondolod atv annyira fontos ügy operett törzs duma állítólag ',
#  ' katalin marosi immunemlékezet magyarázat gyermek kevesen ',
#  ' máshol jobb helyzet egészséges sokáig nyugdij kitaláltak halál oltás vetlenul egészségügy magankorhazak ',
#  ' ehyáltalán lögy semmelweisz rektor vakcin rendesen letesztelv év tesztelés ',
#  ' szlovákia milló adag létező vakcina felkészítés kötelező_oltás egészségügyi miniszt oltás addig szájkosár ember berlin ember ',
#  ' első oltassátok ',
# ...
#  ' mennyire gyerek világ vég első adandó alkalom örég otthon elzüllik börtön előbb hal ',
#  ' papp zsófia klasszikus là orrànàl tovàbb mamàr tehàt éhezés ',
#  ' inkabb bankod saj lakas egyed teli has gyerm etelem ',
#  ' tóth marci szabadúszó önmegvalósítassz gyerek nélküli élet önmegvalósí ezáltal boldog számotvetnie ugyan életcél jól ',
#  ' egyébként második ember ország krónikus_beteg ',
#  ' krcsmarikné ilona kérdés ',
#  ' ferenc aham szó vérbetegség ',
#  ' hamar vakcina ',
#  ' tegnap millió vírus társbetegség gondolod kötelező_oltás x ember influenza_oltás ingyen idős gyógyszergyártó bukszáj soha igény szervezet ',
#  ' hittem vakcinából klonozzák ',
#  ' mónika tarné se írás esküsz általános diploma oltás köz vírus ',
#  ' öszterling bernad általános_iskola vìrusteszt oltóanyag kìsérlet óriási különbség oltóanyagra szükség itthon t sabin_csepp egészséges gyerek ',
#  ' haszontalan ismételt oldal ',
#  ' mészáros tiborcz szálloda ',
#  ' gusztustalanok pénzcentrum ',
#  ' törőltem oldal facebookomrol xd probléma ',
#  ' cseh lengyel szlovák ',
#  ' ferenc mayer kár ',
#  ' franc sejtkultúra francia ',
#  ' anyó fotó megható humor család ',
#  ' géza domokos videó tuti valós adat interneten videó védőoltás autizmus gyíkember nanochip ember tájékoztatás mégse hiányolod ',
#  ' laszlo beiermeister mester moszkovszkij virtuóz ',
#  ' vera kökény pontos ',
#  ' járványos betegség ember maszk száj orr vírus szem látható apró lény szem fül pólus állandó található vegyi anyag galiba szervezet jó immunrendszer erősítés különféle vitamin d_vitamin c_vitamin mennyiség magnézium kálcium mozgás levegő utolsósorban kedély nevetés szervezet pozitív energia ',
#  ' david csonka sajtkultúra gyors szemüveg ',
#  ' david csonka ',
#  ' koronavírusos migráns ',
#  ' hónap július november ',
#  ' mèg egyàtalà ',
#  ' politikai gazdasági élet szereplő korona egészen addig százezer munkanélk ember kirobbant forradalom szarzsák első_hullám ',
#  ' október hová naptár ',
#  ' márk mailach sokmillió vírus ritka védőoltás bármily vírus változat ',
#  ' nyugodt család sima_influenza különben korona oltóanyag állandóan vírus mire vakcina mutálódott fajta oltás nyugodt sokáig rohadt maszk vírus oxigénhiány káros egészség perc rossz ',
#  ' arctalan gábor nyálasi mennyit nyalás ',
#  ' várható únió indokolatlan határzár ',
#  ' kormánytag kölyk unoka teszteltetne értékes gyerek ',
#  ' hazug csaló lopo cèl kènyszer vakcina ès csipelès kiakar ',
#  ' miklós erdős ja banda nyakára ',
#  ' hol védő_oltás ',
#  ' lilian németh nyugodt kötelező mire következmény ',
#  ' második_hullám orbán jó migráns szükség jónép ',
#  ' gabber tóth választás ',
#  ' gabber tóth igaz ',
#  ' mirol bez ',
#  ' hazank igaz mar amerikai ceg verplazma ertekesites gyerek messenger rna alapu oltas beep kemeny dolog maszk lepes szolgalelkulet elismerese oltas elfogadasa kapitulacio ',
#  ' mária farkas érv gyerekem szültel csicska gyerekmentes ja boldogan ',
#  ' alexandra mária farkas fogalom szó jelentés valamelyik ősanya csoprot puffogtat oldal ',
#  ' csilla farkas azóta év anyucika apucika nap élet ',
#  ' mária farkas tudomány álláspont gyerekmentes övezet ',
#  ' györgyi pál coronahisztis oltások tekintet oltásellenes szakértő bolygók laposföldes üregesholdas üregesföldes szakért ',
#  ' komoly véret örökítés komoly pezsgős fürdőkád gyermek gyávaság gyerek magányos hoppá unoka késő ',
#  ' gabriella farkas valahol nevelés akarat idős_otthon pénzéhes karrierista szó se gyermek vállalás optimális döntés igazából önmegvalósítás hiányos gyerek ',
#  ' tóth marci troll ',
#  ' tóth marci franc egyáltalán addig ',
#  ' gyongyi seles hülye hondolkozol ',
#  ' random fb poszt hülye ',
#  ' vakcina ország polc minek ',
#  ' gergő czunyi parancsolsz ',
#  ' biztos egyszer ',
#  ' honnan ',
#  ' pénz ',
#  ' tamás lakosság fertőzés valószínű influenza_védőoltás egyébként kötelező veszélyeztetett réteg valószínűleg ingyenes kötelező ingyenesség állam ',
#  ' hülyeség ',
#  ' részem nyugodt ',
#  ' parlament beadatna sor idióta cilikét hagy biztos biztos ',
#  ' biztos ',
#  ' csaba seres különösen téma betegség gyakran egyszerű megelőzés ',
#  ' bátor szemét seggnyaló ',
#  ' heni gombos teljes érvelés rendesen tesztelve oltás pontos kritérium mielőtt furcsa vírus mennyire veszélyes védekezési mód szerinte kommentelő rész végig chip hasonló ',
#  ' kanyó zsolt igy igaz ',
#  ' kanyó zsolt chipp mindenk iott zsebeb név okostelef okos barkirol ',
#  ' péter várhelyi szerencsere kulonoseb hivatalos termeszetgyogyaszat gyogyszeripar letezett tovab nyugati orvoslas tuneti kezelesrol szol legtobb vegzett termeszetgyogyasz eltuntetese globalis gazdasagilag tovab modern egeszsegugy szamos komoly betegseg eset kalap ala kuruzsl termeszetgyogyasz mennyire agymosott gyogyszerlobbista ',
#  ' portál értelmes ember tiszta oltóanyag ',
#  ' kizárt gyengitett idegen talány orosz biztos vack ',
#  ' megnyugtató irónia többség vírus fél annyira veszélyes média manipuláció oltás poltikus főleg média oltás manipulálás ',
#  ' vékony erzsébet zsóka egyszerű megoldás adass ',
#  ' vakcina nyugodt lehetőség politikus ',
#  ' oltat csuti rém ',
#  ' gyerek na csinálok csúnya ',
#  ' krisztián toti tiszta több ',
#  ' egyszer szar két ',
#  ' gulyás tibor nyájmmunitás rész jelenleg vakcina egyszer se megint pont cél oltás megbetegedés szám védve egyébként ok ',
#  ' istene vakcina vakcina két lájkvadászat elég undi műfaj ',
#  ' márton takács pontos ',
#  ' adatna ',
#  ' két anya adat biztos ',
#  ' péter várhelyi esetleg dok szó ',
#  ' nehéz pici világ vakcina előállítáás mindeki ',
#  ' magyar_állampolgár hét karant covi teszt ',
#  ' patrik geiszt lebegsz ',
#  ' annyat ',
#  ' természetes normális ember érdekes kis szünet vírus kapcsolatos kitalálás szó népesedt emberiség valahányadát probléma ember szervezet alap imunis vírus vírus egyben biztos ember orra kérdés ember meddig ',
#  ' marcsi batyai tóthné sajnos elő oltás biztos adat védőoltás ellenes oltás hivatal szálloda vajon ',
#  ' zoltan vajda igaz nyomkodjú mag ',
#  ' tényleg ember ',
#  ' vakcina két ',
#  ' biztos ',
#  ' két vakcina először másodszorra biztos eza népírtás ',
#  ' marcsi batyai tóthné bar adag ',
#  ' marcsi batyai tóthné mielőtt vadul lehülyé adat csupán sokan lehetőség ',
#  ' oltás influenza ugyanakkor él immunerősítő drog alkalmazás katasztrófa autoimmun betegség gyógymód helyes működő immunrendszer gyógyulás leépülés fázis szteroid vélemény tesó tesó ',
#  ' gabor tamas tanay sajnos mikroszkóp apró papucsállatka bástya iskola kocsma szerencsétlen vén impotens fasz ',
#  ' lendvay utca tudósai május dátum brit tudós ',
#  ' nyar kaja osszeg ajanlatos strand amig oltas infektologus kloty haszn igy nezz haj ',
#  ' mongol vakcina idióta szállóige mongolidióta kifejezés ',
#  ' tömeges beadható vakcina valószínűség kérdéses mellékhatás hosszú sajnos ',
#  ' krisztina stefkovicsné jelentés anyakönyvi kivonat oltási_könyv alap állampolgár védett hányan unokahugi svédország oltás szokás gyógyszer oltóanyag ellátás raktárkészlet ellenőrzes folyamatos biztosìtás kismama kisbaba rizikós kismama immunitás hiányos ',
#  ' kúrva anya oltás szer pénz lehuzás kamu szer undórító magyar_kormány hála ',
#  ' irániak kedves fideszes ',
#  ' reggel több ',
#  ' frány migráns ',
#  ' tibor somogyi hamar csod idoszak kibekkeleni amig alternativa gyorsteszt nap munkakepes lakossag szol jelenleg kibir addig amig mukodo gyorsteszt oltasfél utana influenza forgatokonyv leheto eljen addig nagy szam ',
#  ' róbert szekula általános általános sokáig vakcina_előállítás ',
#  ' sándor tünde ész gyors oltóanyag ',
#  ' lenkei szcientológiai szekta tag vezető pozíció földönkívüli gyikleny galaxis nehéz ',
#  ' doktor orvos biztos orvos ',
#  ' tánczos erzsébet kommentemet ',
#  ' főleg előtte lévő nagyleleplező emberiség hülyeség kis fény ',
#  ' dóra takács ',
#  ' linterné farkas nóra olaszok spanyol angol beteg alapbetegség éves cukorbeteg sokáig eleve rossz immun redsze az veszélyes járvány ',
#  ' levente czako január házi_orvos tartós gyógyszer hónap gondoskodjú beszállítási stopp eüs plussz oltás kert szerencsés december ausztria ',
#  ' bcg_oltás jelen ország védettség kicsi remény idős olthatna kor ',
#  ' erika danka tbc ember gyógyszer vakcina mégis sokan _év miatta maszk szigorító intézkedés tapasztalat helyzet jelenleg ember kár orvos betegség normális mindenhol covidos krónikus_betegség szenvedő emiatt normalis megfelelő kezelés sor bánásmód ',
#  ' tényleg amig önkorányzat helyette feladat mell döngetés szerencse szerencséje mult okos vezető kötelező_oltás nép érdek ',
#  ' szabolcs farkas szabi sír szimplán elborult fatalista barom vegán kezdv ökofasiszta valláskátoult egészen oltásellenes háttérhatalmazós végitéletváró lelki nyomorulta békés szimplán kurva any kísértés ',
#  ' vakcina lejar egesz vilag hiszteria ',
#  ' bogyó sándor divatos konteó covi gazdaság háttérhatalom megölethess g chipes oltás szokásos baromság ',
#  ' tbc elleni védô oltás c_vitamin betegség kivåltó okaiba ',
#  ' boris világhírű öntömjénező vonósnégyes brácsás ',
#  ' fideszes számmisztika mongóliai magyar vakcinagyár munkahely ',
#  ' hullám első múlt gyógyszer védőoltás hiába összeesküvés_elmélet vírus emberek anyagilag törödj ',
#  ' vírus vakcina ',
#  ' spanyolnátha járvány öszi tavaszi hullám első két kör kemény vesztes háború kivérzett ország hatvanezer ember elv tőle azóta hullám igaz vakcina ',
#  ' vezetés nép ',
#  ' regisztràlt olvasó cikk bevezető hozzàfűzne elővigyàzatossàg kezem hàny ember maszk gumikesztyű elmúlt két_hónap bolti dolgozó pénztàros igazán ',
#  ' cseh éva folyamatos nehéz oltás ',
#  ' cseh éva valami oltás lefutásu idő év ',
#  ' part víz oltási szándék ',
#  ' holp mihály végre kezdeményezés ',
#  ' bátor ember parlament kísérleti ',
#  ' szó ember önrendelkezési jog test invazív beavatkozás műtét hozzájárulás tesztalanyo ember es vallal felelősség mellekhataser haláler oltás év mutálódó vírus vakcína hónap emberek ',
#  ' kuka idei szezon zárt kapus futam lehetőség gyors ',
#  ' miklósné somogyi oltás_hely sokan ',
#  ' csaba pájer szép hol olyanat ilyen fatalista se vega vallásos oltásellenes háttérhatalmozós házszám baj ',
#  ' vakcina addig levegő élet járványügyi időpont influenzás nyár kolleganő egyszer végig nemcsak külkereskedelmi osztály ',
#  ' veszélyeztetett ',
#  ' ja gyerek ',
#  ' edigse semmily oltás érdekes semi baj ',
#  ' biztos egyszer anya kopasz ',
#  ' bebe ny mindenhova szép ',
#  ' kettőt biztos hatás fene ',
#  ' sajtkultúra ',
#  ' david csonka francia hír olvasva meglepő ',
#  ' gasztrofixáltak ',
#  ' panna klaudia lakos idős rész ingyen influenza_elleni védőoltás igy influenzás makacs takonykór járó kórokozó védőoltás influenzá kicsi dolog ',
#  ' normalis lockdown teszteles megfelelo tajekoztatas kozossegi osszeroffenes nyitva tarto etterem kavez kocsom uzlet jarmu maszk onmaga sajnos eleg semminel tobb szazalekos vedettség betartatva betartva mell protokoll enyhites het pe lehetseges priti patel amig vakcina addig rend elet szokasos kerekvagasba kulonbozo intezkedes jarni ',
#  ' politikus kú hét ',
#  ' oltás hydroxy kezelés ',
#  ' heni gombos pontos ',
#  ' orbán_család elsőnek ',
#  ' péter várhelyi kénen kitalal penz zsebre ',
#  ' oltás pontos honnan vegyi anyag biztos pontosabban vegyi anyag teljes előtt száz_év halálos_vírus vírus népesség hatékony szó irta szerverzet imunis egyszer halálos cél nép csökkentés ',
#  ' kotelezo ',
#  ' marcsi batyai tóthné szerintem sajnos biztos ',
#  ' istván polgár ',
#  ' biztos soha csalad vana oltas es makk egezseges ',
#  ' hülye kitudja lassú méreg egyszer kinyir ember találgatóz kitalált szar ',
#  ' influenza_oltás év mégis ember örökélet kutatás emberiség veszte ',
#  ' vakcinat mire kikiserletez ev utanna beadjú legal ev mire mellékhatás immunrendszer erositeni es gyümölcs ',
#  ' először politikus kutató ',
#  ' incze levente olyam kár ',
#  ' marcsi batyai tóthné ',
#  ' incze levente kb ilyennel álltal fülke egyik kocsi ',
#  ' vakcina betegség ',
#  ' szó közben sátánfattya hatalom íz totális város pénze polgármester semmi orbáni hatalom lecsó iszonyú sebesség rendelet előre forgatókönyv tag gyorsak hol szabadság morzsa európa döbbent ügy gyors kemény csapva szabadság morzsa pénzéhes ganaj dühödt bosszú ellenkezés hosszú lista ',
#  ' szép európai ',
#  ' lászló árpási védõoltás bevezetés ',
#  ' ember ezer forint kenyér stb oltóanyag hatóanyag ',
#  ' világ ország szükség emberek ',
#  ' keveri sz ',
#  ' elöl migráns ',
#  ' holnap hullám tetőzés választás nap halasztva év ',
#  ' első ',
#  ' mag munkanélküliség pénztelenség hatalom lopás rablás háború ember jobb kussolna lassú szép bárómság hatalmas kamu járvány háború rohadék politikus ',
#  ' rendelés koronavírus politikus kinaiak minél ló segély pénz könnyű ',
#  ' esetleg óra perc hálás ész hír ',
#  ' mária antalné takács elérhetőség kontakt ',
#  ' küsmödi katalin tokmindegy kamuprofil ',
#  ' edina mónika molnár veszélyeztetett_korosztály sima influenza_elleni oltás problem solved szétkúrni gazdaság ',
#  ' zsuzsi józsa magaom példáz unoka nál latens ',
#  ' pontatlan ruppert mihály kellőképpen tájékozott kötelező bcg_oltás unokanővér éves típusú kijelentés minimum ember ',
#  ' margit valentinyi kötelező jelleg ',
#  ' álmodozza teljes szer létező max tünet ',
#  ...]

# %%
new_sigbigrams = []

for sentence in sigbigrams:
    new_string = sentence.replace(" covi_vírus ", " covid_vírus ")
    new_string2 = new_string.replace(" covi ", " covid ")
    new_string3 = new_string2.replace(" covi_osztály ", " covid_osztály ")
    new_string4 = new_string3.replace(" covi_vakcina ", " covid_vakcina ")
    new_string5 = new_string4.replace(" covi_oltás ", " covid_oltás ")
    new_string6 = new_string5.replace(" covi_elleni ", " covid_elleni ")
    new_string7 = new_string6.replace(" ast_zeneca ", " astrazeneca ")
    new_string8 = new_string7.replace(" orosz_vakcinat ", " orosz_vakcinat ")
    new_string9 = new_string8.strip()
    
    new_sigbigrams.append(new_string9)

# %%
import operator
from collections import Counter

txts = []

for text in new_sigbigrams:
    txt = text.strip().split()
    txt = [w for w in txt if len(w) > 3]
    txts.append(txt)

        
wordlist = list(itertools.chain(*txts))
wfreq = Counter(wordlist)
sorted_wfreq = sorted(wfreq.items(),
                      key=operator.itemgetter(1),
                      reverse=True)

with codecs.open('wfreq.tsv', 'w', 'utf-8') as f:
    for e in sorted_wfreq:
        o = e[0] + '\t' + str(e[1]) + '\n'
        f.write(o)

wd_docfreq = {}
for d in txts:
    d = list(set(d))
    for w in d:
        if w not in wd_docfreq.keys():
            wd_docfreq[w] = 1
        else:
            wd_docfreq[w] += 1

sorted_docfreq = sorted(wd_docfreq.items(),
                        key=operator.itemgetter(1),
                        reverse=True)

with codecs.open('docfreq.tsv', 'w', 'utf-8') as f:
    for e in sorted_docfreq:
        o = e[0] + '\t' + str((e[1]/len(txts))) + '\n'
        f.write(o)

# %%
stopwords = pd.read_csv('stopszavak.txt', delimiter = "\t", header = None, names = ["words"])

# %%
stopwords
# Out:
#         words
# 0       ember
# 1      biztos
# 2        igaz
# 3      lászló
# 4      sajnos
# ..        ...
# 195      rita
# 196     hátha
# 197   melinda
# 198     végig
# 199  hirtelen
#
# [200 rows x 1 columns]

# %%
new_sigbigrams2 = []
for text in new_sigbigrams:
    for word in list(stopwords["words"]):
        text = text.replace(word + " ", '')
    text = text.replace("pfizer_vakcina ", "pfizer ")
    text = text.replace("pfizer_oltás ", "pfizer ")
    text = text.replace("pfizer_biontech ", "pfizer ")
    text = text.replace("astrazenec ", "astrazeneca ")
    text = text.replace("moderna_vakcina ", "moderna ")
    text = text.replace("szputnyik ", "orosz_vakcina ")
    text = text.replace("szputnyik_v ", "orosz_vakcina ")
    text = text.replace("orosz_oltás ", "orosz_vakcina ")
    text = text.replace("orosz_oltóanyag ", "orosz_vakcina ")
    text = text.replace("ruszki_vakcina ", "orosz_vakcina ")
    text = text.replace("kinai_vakcina ", "kínai_vakcina ")
    text = text.replace("kínai_oltás ", "kínai_vakcina ")
    text = text.replace("kínai_oltóanyag ", "kínai_vakcina ")
    text = text.replace("sinopharm ", "kínai_vakcina ")
    text = text.replace("orbán ", "orbán_viktor ")
    text = text.replace("vitya ", "orbán_viktor ")
    text = text.replace("miniszterelnök ", "orbán_viktor ")
    text = text.replace("zorbán ", "orbán_viktor ")
    text = text.replace("szijjártó ", "szijjártó_péter ")
    text = text.replace("szíjjártó ", "szijjártó_péter ")
    text = text.replace("szijártó ", "szijjártó_péter ")
    text = text.replace("szíjártó ", "szijjártó_péter ")
    text = text.replace("külügyminiszter ", "szijjártó_péter ")
    text = text.replace("cecilia ", "müller_cecília ")
    text = text.replace("cecília ", "müller_cecília ")
    text = text.replace("ceci ", "müller_cecília ")
    text = text.replace("cilike ", "müller_cecília ")
    text = text.replace("müller ", "müller_cecília ")
    text = text.replace("bill ", "bill_gates ")
    text = text.replace(" gates ", "bill_gates ")
    text = text.replace("gődény ", "gődény_györgy ")
    text = text.replace("gödény ", "gődény_györgy ")
    text = text.replace("szlávik ", "szlávik_jános ")
    text = text.replace("szlávik_doktor ", "szlávik_jános ")
    new_sigbigrams2.append(text)

# %%
table_new["sigbigrams"] = new_sigbigrams2

# %%
wordcount = []
for item in list(table_new["sigbigrams"]):
    wordcount.append(len(item.split()))

# %%
table_new["wordcount"] = wordcount

# %%
table_new2 = table_new[~(table_new["wordcount"] < 3)]
table_new2.drop(columns = ["wordcount"], inplace = True)
table_new2 = table_new2.reset_index(drop=True)
table_new2.shape
# Out:
# C:\Users\THINKPAD\Anaconda3\lib\site-packages\pandas\core\frame.py:4174: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
# (1429718, 9)

# %%
from collections import Counter
import operator

txts2 = []

for text in list(table_new2["sigbigrams"]):
    txt = text.strip().split()
    txt = [w for w in txt if len(w) > 3]
    txts2.append(txt)

        
wordlist = list(itertools.chain(*txts2))
wfreq = Counter(wordlist)
sorted_wfreq = sorted(wfreq.items(),
                      key=operator.itemgetter(1),
                      reverse=True)

with codecs.open('wfreq2.tsv', 'w', 'utf-8') as f:
    for e in sorted_wfreq:
        o = e[0] + '\t' + str(e[1]) + '\n'
        f.write(o)

wd_docfreq = {}
for d in txts2:
    d = list(set(d))
    for w in d:
        if w not in wd_docfreq.keys():
            wd_docfreq[w] = 1
        else:
            wd_docfreq[w] += 1

sorted_docfreq = sorted(wd_docfreq.items(),
                        key=operator.itemgetter(1),
                        reverse=True)

with codecs.open('docfreq2.tsv', 'w', 'utf-8') as f:
    for e in sorted_docfreq:
        o = e[0] + '\t' + str((e[1]/len(txts))) + '\n'
        f.write(o)

# %%
content_words = []
of = codecs.open('contentwords6.tsv', 'w', 'utf-8')
with codecs.open('docfreq2.tsv', 'r', 'utf-8') as input_file:
    for l in input_file:
        wd, dfreq = l.strip().split('\t')
        dfreq = float(dfreq)
        if dfreq > 0.00014:
            content_words.append(wd)
            o = wd + '\t' + str(dfreq) + '\n'
            of.write(o)
of.close()

# %%
input_file = pd.read_table("contentwords6.tsv", header = None, names = ["words", "freq"])
input_file.head()
# Out:
#      words      freq
# 0    oltás  0.061940
# 1  vakcina  0.059853
# 2    vírus  0.028212
# 3   ország  0.019714
# 4    orosz  0.017721

# %%
content_words = list(input_file["words"])

clear_text = []
files = list(table_new2["sigbigrams"])
for f in files:
    text = ""
    txt = ""
    txt = f.strip().split()
    for cw in txt:
        if cw in content_words:
            text += cw + " "
    clear_text.append(text)

# %%
len(clear_text)
# Out:
# 1429718

# %%
table_new2["clear_text"] = clear_text

# %%
table_new3 = table_new2[~(table_new2["clear_text"] == "")]
table_new3 = table_new3.reset_index(drop = True)
table_new3.head()
# Out:
#                                   id  \
# 0  1866276730170800_1866679230130550
# 1  1188841988144997_1188958054800057
# 2  1188841988144997_1188958114800051
# 3  1188841988144997_1188967994799063
# 4  1188841988144997_1188982634797599
#
#                                     Content of posts              Created  \
# 0  Hisszuk vagy nem az ellenszer mar meg van csak...  2020-04-01 05:52:49
# 1  Klára Pásztor-Búza Igeen és különösen az időse...  2020-07-01 16:07:51
# 2  Kedves Tünde! Attol, hogy CF-ek vagyunk, meg v...  2020-07-01 16:07:57
# 3  Egyébként mi az h ha lefogyunk jöhet a gyerek?...  2020-07-01 16:23:18
# 4  Boda Tündi  Szerintem told el a bicajt. Te aka...  2020-07-01 16:47:29
#
#              Domain                                           Keywords  \
# 0  www.facebook.com  https://www.origo.hu/tudomany/20200331-a-fel-v...
# 1  www.facebook.com                                          oltásokat
# 2  www.facebook.com                                          oltásokat
# 3  www.facebook.com                                          oltásokat
# 4  www.facebook.com                                          oltásokat
#
#                                         text_nopunct     date  \
# 0  Hisszuk vagy nem az ellenszer mar meg van csak...  2020-04
# 1  Klára Pásztor Búza Igeen és különösen az időse...  2020-07
# 2  Kedves Tünde Attol hogy CF ek vagyunk meg van ...  2020-07
# 3  Egyébként mi az h ha lefogyunk jöhet a gyerek ...  2020-07
# 4  Boda Tündi Szerintem told el a bicajt Te akars...  2020-07
#
#                                            kommentek  \
# 0  hisszuk ellenszer var sulyosabb helyzet penz v...
# 1                 klára igeen különös idősebb gyerek
# 2  tünde attol emiatt igazan aggodalmaskodn igazi...
# 3  egyébként gyerek súly kötve vékony gyerek kövé...
# 4  boda tündi szerintem bicaj puttony év tartó ra...
#
#                                           sigbigrams  \
# 0  hisszuk ellenszer var sulyosabb helyzet penz v...
# 1                 klára igeen különös idősebb gyerek
# 2  attol emiatt igazan aggodalmaskodn erzelem ele...
# 3         gyerek súly kötve vékony gyerek kövér dddd
# 4  boda tündi szerintem bicaj puttony év tartó ra...
#
#                                           clear_text
# 0                   ellenszer helyzet penz veletlen
# 1                      klára különös idősebb gyerek
# 2       attol emiatt igazan eleg azer csonka gyerek
# 3                    gyerek súly kötve gyerek kövér
# 4  boda tündi szerintem tartó állandóan élet elev...

# %%
table_new3.shape
# Out:
# (1378993, 10)

# %%
table_new3.to_csv("df_final0810.csv", index = False)

# %%
final = pd.read_csv("df_final0810.csv", sep = ",", encoding = "utf8")
final.head()
# Out:
#                                   id  \
# 0  1866276730170800_1866679230130550
# 1  1188841988144997_1188958054800057
# 2  1188841988144997_1188958114800051
# 3  1188841988144997_1188967994799063
# 4  1188841988144997_1188982634797599
#
#                                     Content of posts              Created  \
# 0  Hisszuk vagy nem az ellenszer mar meg van csak...  2020-04-01 05:52:49
# 1  Klára Pásztor-Búza Igeen és különösen az időse...  2020-07-01 16:07:51
# 2  Kedves Tünde! Attol, hogy CF-ek vagyunk, meg v...  2020-07-01 16:07:57
# 3  Egyébként mi az h ha lefogyunk jöhet a gyerek?...  2020-07-01 16:23:18
# 4  Boda Tündi  Szerintem told el a bicajt. Te aka...  2020-07-01 16:47:29
#
#              Domain                                           Keywords  \
# 0  www.facebook.com  https://www.origo.hu/tudomany/20200331-a-fel-v...
# 1  www.facebook.com                                          oltásokat
# 2  www.facebook.com                                          oltásokat
# 3  www.facebook.com                                          oltásokat
# 4  www.facebook.com                                          oltásokat
#
#                                         text_nopunct     date  \
# 0  Hisszuk vagy nem az ellenszer mar meg van csak...  2020-04
# 1  Klára Pásztor Búza Igeen és különösen az időse...  2020-07
# 2  Kedves Tünde Attol hogy CF ek vagyunk meg van ...  2020-07
# 3  Egyébként mi az h ha lefogyunk jöhet a gyerek ...  2020-07
# 4  Boda Tündi Szerintem told el a bicajt Te akars...  2020-07
#
#                                            kommentek  \
# 0  hisszuk ellenszer var sulyosabb helyzet penz v...
# 1                 klára igeen különös idősebb gyerek
# 2  tünde attol emiatt igazan aggodalmaskodn igazi...
# 3  egyébként gyerek súly kötve vékony gyerek kövé...
# 4  boda tündi szerintem bicaj puttony év tartó ra...
#
#                                           sigbigrams  \
# 0  hisszuk ellenszer var sulyosabb helyzet penz v...
# 1                 klára igeen különös idősebb gyerek
# 2  attol emiatt igazan aggodalmaskodn erzelem ele...
# 3         gyerek súly kötve vékony gyerek kövér dddd
# 4  boda tündi szerintem bicaj puttony év tartó ra...
#
#                                           clear_text
# 0                   ellenszer helyzet penz veletlen
# 1                      klára különös idősebb gyerek
# 2       attol emiatt igazan eleg azer csonka gyerek
# 3                    gyerek súly kötve gyerek kövér
# 4  boda tündi szerintem tartó állandóan élet elev...

# %%
import pandas as pd
import codecs
import gensim
import gensim.corpora as corpora
import itertools
import logging
import numpy as np
import os
import pyLDAvis.gensim
import stat
from collections import defaultdict
from gensim.corpora import MalletCorpus
from gensim.models import CoherenceModel
from os import listdir
from os.path import join, isfile

# %%
txt = list(final["clear_text"])

# %%
txts = []
for t in txt:
    txts.append(t.strip().split())
words = list(itertools.chain(*txts))
len(words)
# Out:
# 6285615

# %%
dictionary = corpora.Dictionary(txts)
dictionary.save('dictionary.dict') # a dictionary mentése (figyelj az útvonalra)

# %%
corpus = [dictionary.doc2bow(text) for text in txts]
MalletCorpus.serialize("corpus.mallet", corpus, dictionary) # a corpus mentése (figyelj az útvonalra)

# %%
mallet_path = "C:/Users/THINKPAD/Downloads/mallet-2.0.8/mallet-2.0.8/bin/mallet"
os.environ.update({'MALLET_HOME': r'C:/Users/THINKPAD/Downloads/mallet-2.0.8/mallet-2.0.8/'})

# %%
logging.basicConfig(filename='C:/Users/THINKPAD/Downloads/gensim.log', # útvonal!!!
                    format="%(asctime)s:%(levelname)s:%(message)s",
                    level=logging.INFO)

# %%
of = codecs.open('C:/Users/THINKPAD/Downloads/coherence_values3.txt', 'w', 'utf-8')
for run_number in range(3):
    rs = 1
    for tn in range(5, 15):
        np.random.seed(123)
        model = gensim.models.wrappers.LdaMallet(mallet_path,
                                                 corpus=corpus,
                                                 num_topics=tn,
                                                 id2word=dictionary,
                                                 random_seed=rs+run_number)
        rs += 1
        lda = gensim.models.wrappers.ldamallet.malletmodel2ldamodel(model)
        lda.save(('C:/Users/THINKPAD/Downloads/lda_modellek3/lda_t' + str(tn) + '_r' + str(run_number) +'.model'), ignore=())

        coherence_model = CoherenceModel(model=model,
                                         texts=txts,
                                         dictionary=dictionary,
                                         coherence='c_v')
        coherence_value = coherence_model.get_coherence()
        exp =  'topic ' +str(tn) + ' run' + str(run_number) + ' c_v: ' + str(coherence_value) + '\n'
        of.write(exp)
of.close()

# %%
model = gensim.models.LdaModel.load('C:/Users/THINKPAD/Downloads/lda_modellek3/lda_t14_r1.model')

# %%
model[corpus[3]]
# Out:
# [(0, 0.06493506493507431),
#  (1, 0.06493506493507431),
#  (2, 0.08285850411257313),
#  (3, 0.06493506493507431),
#  (4, 0.0649444907049058),
#  (5, 0.10154765453306416),
#  (6, 0.06493506493507431),
#  (7, 0.10129870129871407),
#  (8, 0.06493506493507431),
#  (9, 0.06493506493507431),
#  (10, 0.06493506493507431),
#  (11, 0.06493506493507431),
#  (12, 0.06493506493507431),
#  (13, 0.06493506493507431)]

# %%
model.show_topic(1)
# Out:
# [('orvos', 0.07602498875237543),
#  ('beteg', 0.05242624132366075),
#  ('teszt', 0.029684775528750273),
#  ('kórház', 0.02478282571665835),
#  ('probléma', 0.017993960976898163),
#  ('háziorvos', 0.015932456055922518),
#  ('ismerős', 0.013647117810193817),
#  ('érdekes', 0.01357549114627284),
#  ('dolgozó', 0.013188259494450053),
#  ('virológus', 0.012241444530744626)]

# %%
vis = pyLDAvis.gensim.prepare(model, corpus, dictionary, sort_topics=False)
pyLDAvis.save_html(vis, 'C:/Users/THINKPAD/Downloads/lda_modellek3/vizu/lda_t14_r1.html')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-cf5183c3d7bb> in <module>
# ----> 1 vis = pyLDAvis.gensim.prepare(model, corpus, dictionary, sort_topics=False)
#       2 pyLDAvis.save_html(vis, 'C:/Users/THINKPAD/Downloads/lda_modellek3/vizu/lda_t14_r1.html')
#
# ~\Anaconda3\lib\site-packages\pyLDAvis\gensim.py in prepare(topic_model, corpus, dictionary, doc_topic_dist, **kwargs)
#     116     See `pyLDAvis.prepare` for **kwargs.
#     117     """
# --> 118     opts = fp.merge(_extract_data(topic_model, corpus, dictionary, doc_topic_dist), kwargs)
#     119     return vis_prepare(**opts)
#
# ~\Anaconda3\lib\site-packages\pyLDAvis\gensim.py in _extract_data(topic_model, corpus, dictionary, doc_topic_dists)
#      46           gamma = topic_model.inference(corpus)
#      47       else:
# ---> 48           gamma, _ = topic_model.inference(corpus)
#      49       doc_topic_dists = gamma / gamma.sum(axis=1)[:, None]
#      50    else:
#
# ~\Anaconda3\lib\site-packages\gensim\models\ldamodel.py in inference(self, chunk, collect_sstats)
#     678             Elogthetad = Elogtheta[d, :]
#     679             expElogthetad = expElogtheta[d, :]
# --> 680             expElogbetad = self.expElogbeta[:, ids]
#     681
#     682             # The optimal phi_{dwk} is proportional to expElogthetad_k * expElogbetad_w.
#
# KeyboardInterrupt:

# %%
pyLDAvis.display(vis)

# %%
def format_topics_sentences(ldamodel=model, corpus=corpus, texts=final["clear_text"]):
    # Init output
    sent_topics_df = pd.DataFrame()

    # Get main topic in each document
    for i, row in enumerate(ldamodel[corpus]):
        row = sorted(row, key=lambda x: (x[1]), reverse=True)
        # Get the Dominant topic, Perc Contribution and Keywords for each document
        for j, (topic_num, prop_topic) in enumerate(row):
            if j == 0:  # => dominant topic
                wp = ldamodel.show_topic(topic_num)
                topic_keywords = ", ".join([word for word, prop in wp])
                sent_topics_df = sent_topics_df.append(pd.Series([int(topic_num), round(prop_topic,4), topic_keywords]), ignore_index=True)
            else:
                break
    sent_topics_df.columns = ['Dominant_Topic', 'Perc_Contribution', 'Topic_Keywords']

    # Add original text to the end of the output
    contents = pd.Series(texts)
    sent_topics_df = pd.concat([sent_topics_df, contents], axis=1)
    return(sent_topics_df)


df_topic_sents_keywords = format_topics_sentences(ldamodel=model, corpus=corpus, texts=final["clear_text"])

# Format
df_dominant_topic = df_topic_sents_keywords.reset_index()
df_dominant_topic.columns = ['Document_No', 'Dominant_Topic', 'Topic_Perc_Contrib', 'Keywords', 'Text']

# Show
df_dominant_topic.head(10)
# Out:
#    Document_No  Dominant_Topic  Topic_Perc_Contrib  \
# 0            0             0.0              0.1032
# 1            1             7.0              0.1032
# 2            2             0.0              0.1328
# 3            3             5.0              0.1015
# 4            4             7.0              0.1111
# 5            5             7.0              0.1147
# 6            6             7.0              0.1262
# 7            7             7.0              0.0978
# 8            8            10.0              0.1071
# 9            9             2.0              0.1134
#
#                                             Keywords  \
# 0  oltas, virus, kamu, oltat, vicc, jobb, sajnos,...
# 1  oltás, covid, gyerek, védőoltás, betegség, inf...
# 2  oltas, virus, kamu, oltat, vicc, jobb, sajnos,...
# 3  kormány, orbán_viktor, fidesz, politikus, orsz...
# 4  oltás, covid, gyerek, védőoltás, betegség, inf...
# 5  oltás, covid, gyerek, védőoltás, betegség, inf...
# 6  oltás, covid, gyerek, védőoltás, betegség, inf...
# 7  oltás, covid, gyerek, védőoltás, betegség, inf...
# 8  élet, rossz, isten, egészség, szint, fontos, c...
# 9  maszk, kötelező, otthon, szabad, munka, járván...
#
#                                                 Text
# 0                   ellenszer helyzet penz veletlen
# 1                      klára különös idősebb gyerek
# 2       attol emiatt igazan eleg azer csonka gyerek
# 3                    gyerek súly kötve gyerek kövér
# 4  boda tündi szerintem tartó állandóan élet elev...
# 5  krisztian rettegés óvatosság anyuka férj védőo...
# 6  önző döntés mellesleg gyerek gyermek apróság u...
# 7    edina mellesleg gyerek gyerek utáni vágy érzés
# 8                                     tamásné érzés
# 9  boda tündi ugyanitt szabad_akarat gyermek ingy...

# %%
df_dominant_topic["Original_text"] = final["Content of posts"]

# %%
df_dominant_topic[df_dominant_topic["Dominant_Topic"] != 0.0]
# Out:
#          Document_No  Dominant_Topic  Topic_Perc_Contrib  \
# 1                  1             7.0              0.1032
# 3                  3             5.0              0.1015
# 4                  4             7.0              0.1111
# 5                  5             7.0              0.1147
# 6                  6             7.0              0.1262
# ...              ...             ...                 ...
# 1378987      1378987             6.0              0.0844
# 1378988      1378988             1.0              0.0879
# 1378989      1378989            10.0              0.1071
# 1378990      1378990             9.0              0.0937
# 1378992      1378992            12.0              0.0847
#
#                                                   Keywords  \
# 1        oltás, covid, gyerek, védőoltás, betegség, inf...
# 3        kormány, orbán_viktor, fidesz, politikus, orsz...
# 4        oltás, covid, gyerek, védőoltás, betegség, inf...
# 5        oltás, covid, gyerek, védőoltás, betegség, inf...
# 6        oltás, covid, gyerek, védőoltás, betegség, inf...
# ...                                                    ...
# 1378987  vakcina, orosz, kínai, orosz_vakcina, pfizer, ...
# 1378988  orvos, beteg, teszt, kórház, probléma, háziorv...
# 1378989  élet, rossz, isten, egészség, szint, fontos, c...
# 1378990  világ, ország, pénz, jobb, ingyen, milliárd, b...
# 1378992  hülye, szar, ember, idióta, oltasd, fideszes, ...
#
#                                                       Text  \
# 1                            klára különös idősebb gyerek
# 3                          gyerek súly kötve gyerek kövér
# 4        boda tündi szerintem tartó állandóan élet elev...
# 5        krisztian rettegés óvatosság anyuka férj védőo...
# 6        önző döntés mellesleg gyerek gyermek apróság u...
# ...                                                    ...
# 1378987                                         hollandia
# 1378988                                       orvos oltas
# 1378989                                        atya isten
# 1378990  fent félelem corona vírusos helyzet félelem ro...
# 1378992                         birka tétel lényeg akarat
#
#                                              Original_text
# 1        Klára Pásztor-Búza Igeen és különösen az időse...
# 3        Egyébként mi az h ha lefogyunk jöhet a gyerek?...
# 4        Boda Tündi  Szerintem told el a bicajt. Te aka...
# 5        Krisztian Köhalmi Ennek semmi köze a rettegésh...
# 6        Makár Papp Katalin mi ez ha nem önző döntés? M...
# ...                                                    ...
# 1378987          Csoky Hollandia Jó, ez egy kép. Bővebben?
# 1378988  Regen ez ugy mukodott. Jott egy virus , szolt ...
# 1378989  Amit én nem akarok le jöhet az atya úr isten i...
# 1378990  Ez arra megy ki hogy az emberekben fent tartsá...
# 1378992  Itt a birkává tétel a lényeg , elvenni a saját...
#
# [1256932 rows x 6 columns]

# %%
df_dominant_topic.to_csv("dominant_topics_t14_r1.csv", index = False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-692767c5a42d> in <module>
# ----> 1 df_dominant_topic.to_excel("dominant_topics_t14_r1.xlsx", index = False)
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, encoding, inf_rep, verbose, freeze_panes)
#    2030             startcol=startcol,
#    2031             freeze_panes=freeze_panes,
# -> 2032             engine=engine,
#    2033         )
#    2034
#
# ~\Anaconda3\lib\site-packages\pandas\io\formats\excel.py in write(self, writer, sheet_name, startrow, startcol, freeze_panes, engine)
#     721         if num_rows > self.max_rows or num_cols > self.max_cols:
#     722             raise ValueError(
# --> 723                 f"This sheet is too large! Your sheet size is: {num_rows}, {num_cols} "
#     724                 f"Max sheet size is: {self.max_rows}, {self.max_cols}"
#     725             )
#
# ValueError: This sheet is too large! Your sheet size is: 1378993, 6 Max sheet size is: 1048576, 16384

# %%
import pandas as pd

# %%
cv = pd.read_table("coherence_values3.txt", sep = " ", header = None, names = ["T", "Topic_number", "Run", "Measure", "CV"])
cv
# Out:
#         T  Topic_number   Run Measure        CV
# 0   topic             5  run0    c_v:  0.329730
# 1   topic             6  run0    c_v:  0.348730
# 2   topic             7  run0    c_v:  0.351860
# 3   topic             8  run0    c_v:  0.382242
# 4   topic             9  run0    c_v:  0.398884
# 5   topic            10  run0    c_v:  0.380665
# 6   topic            11  run0    c_v:  0.402518
# 7   topic            12  run0    c_v:  0.431840
# 8   topic            13  run0    c_v:  0.441751
# 9   topic            14  run0    c_v:  0.441648
# 10  topic             5  run1    c_v:  0.303986
# 11  topic             6  run1    c_v:  0.347730
# 12  topic             7  run1    c_v:  0.368661
# 13  topic             8  run1    c_v:  0.368862
# 14  topic             9  run1    c_v:  0.394194
# 15  topic            10  run1    c_v:  0.395906
# 16  topic            11  run1    c_v:  0.407576
# 17  topic            12  run1    c_v:  0.425344
# 18  topic            13  run1    c_v:  0.435094
# 19  topic            14  run1    c_v:  0.448045
# 20  topic             5  run2    c_v:  0.298413
# 21  topic             6  run2    c_v:  0.321320
# 22  topic             7  run2    c_v:  0.356759
# 23  topic             8  run2    c_v:  0.367560
# 24  topic             9  run2    c_v:  0.394553
# 25  topic            10  run2    c_v:  0.396491
# 26  topic            11  run2    c_v:  0.416792
# 27  topic            12  run2    c_v:  0.422437
# 28  topic            13  run2    c_v:  0.427616
# 29  topic            14  run2    c_v:  0.443399

# %%
from matplotlib.pyplot import figure
import matplotlib.pyplot as plt

figure(figsize=(8, 5), dpi=80)
cv.set_index('Topic_number', inplace=True)
cv.groupby('Run')['CV'].plot(legend=True)
plt.xlabel('Topikok száma')
plt.ylabel('C_v érték')
plt.savefig("cv_14.pdf")

# %%
df_dominant_topic = pd.read_csv("dominant_topics_t14_r1.csv", sep = ",")

# %%
nulla = df_dominant_topic[df_dominant_topic["Dominant_Topic"] == 13.0]

# %%
nulla[nulla["Topic_Perc_Contrib"] >= 0.180].reset_index(drop=True)["Original_text"][3]
# Out:
# 'A kiváló harcosok ,viki,kásler profi,cili nyunyoka, deutcht tompika ,bayer bológató zsoca ,és a többi front ember legyenek az elsők. Nosza rajta.Csak bátran mint mindig.'

# %%
final_df = pd.read_csv("merged_df.csv", sep = ",")

# %%
final2 = final_df[final_df["Len"] >= 5]
final2 = final2.reset_index(drop=True)

# %%
final2.to_csv("final_df_new.csv", index = False)

# %%
txt = list(final2["clear_text"])

# %%
txts = []
for t in txt:
    txts.append(t.strip().split())
words = list(itertools.chain(*txts))
len(words)
# Out:
# 3831421

# %%
dictionary = corpora.Dictionary(txts)
dictionary.save('dictionary.dict') # a dictionary mentése (figyelj az útvonalra)

# %%
corpus = [dictionary.doc2bow(text) for text in txts]
MalletCorpus.serialize("corpus.mallet", corpus, dictionary) # a corpus mentése (figyelj az útvonalra)

# %%
of = codecs.open('C:/Users/THINKPAD/Downloads/coherence_values_uj.txt', 'w', 'utf-8')
for run_number in range(3):
    rs = 1
    for tn in range(5, 42):
        np.random.seed(123)
        model = gensim.models.wrappers.LdaMallet(mallet_path,
                                                 corpus=corpus,
                                                 num_topics=tn,
                                                 id2word=dictionary,
                                                 random_seed=rs+run_number)
        rs += 1
        lda = gensim.models.wrappers.ldamallet.malletmodel2ldamodel(model)
        lda.save(('C:/Users/THINKPAD/Downloads/lda_modellek_uj/lda_t' + str(tn) + '_r' + str(run_number) +'.model'), ignore=())

        coherence_model = CoherenceModel(model=model,
                                         texts=txts,
                                         dictionary=dictionary,
                                         coherence='c_v')
        coherence_value = coherence_model.get_coherence()
        exp =  'topic ' +str(tn) + ' run' + str(run_number) + ' c_v: ' + str(coherence_value) + '\n'
        of.write(exp)
of.close()

# %%
cv = pd.read_excel("coh_value.xlsx")
cv
# Out:
#     Topik      Run0      Run1      Run2
# 0       5  0.372800  0.359854  0.355685
# 1       6  0.385872  0.407400  0.384623
# 2       7  0.416921  0.391916  0.398238
# 3       8  0.402381  0.414623  0.397238
# 4       9  0.401429  0.431161  0.425092
# 5      10  0.419309  0.417952  0.416759
# 6      11  0.429305  0.434827  0.435275
# 7      12  0.451187  0.446656  0.446207
# 8      13  0.459070  0.442421  0.449184
# 9      14  0.469618  0.454483  0.458706
# 10     15  0.469222  0.470093  0.473481
# 11     16  0.465168  0.468118  0.459046
# 12     17  0.459762  0.474504  0.467781
# 13     18  0.480313  0.484459  0.479703
# 14     19  0.466677  0.474294  0.483360
# 15     20  0.493505  0.480312  0.473746
# 16     21  0.496535  0.486965  0.479635
# 17     22  0.474828  0.483641  0.489978
# 18     23  0.486625  0.493671  0.486243
# 19     24  0.483377  0.492255  0.492345
# 20     25  0.507132  0.481296  0.485982
# 21     26  0.481213  0.492626  0.484047
# 22     27  0.483834  0.491572  0.492864
# 23     28  0.502704  0.490332  0.497404
# 24     29  0.482509  0.494132  0.496486
# 25     30  0.500542  0.487727  0.501456
# 26     31  0.499408  0.489679  0.499078
# 27     32  0.495132  0.496222  0.490866
# 28     33  0.494933  0.500267  0.500637
# 29     34  0.501776  0.502069  0.501402
# 30     35  0.510308  0.499039  0.517978
# 31     36  0.489222  0.500062  0.492907
# 32     37  0.500885  0.499530  0.492141
# 33     38  0.503017  0.498637  0.491911
# 34     39  0.491765  0.492689  0.507626
# 35     40  0.497902  0.508710  0.514023
# 36     41  0.508241  0.506953  0.492995

# %%
from matplotlib.pyplot import figure
import matplotlib.pyplot as plt

plt.figure(figsize=(15, 12))
cv.plot(x="Topik", y=["Run0", "Run1", "Run2"], grid = True)
plt.xlabel('Topikok száma')
plt.ylabel('C_v érték')
plt.savefig("cv41_values.png", dpi = 300)

# %%
model = gensim.models.LdaModel.load('C:/Users/THINKPAD/Downloads/lda_modellek_uj/lda_t35_r2.model')

# %%
vis = pyLDAvis.gensim.prepare(model, corpus, dictionary, sort_topics=False)
pyLDAvis.save_html(vis, 'C:/Users/THINKPAD/Downloads/lda_t35_r2.html')
# Out:
# C:\Users\THINKPAD\Anaconda3\lib\site-packages\pyLDAvis\_prepare.py:223: RuntimeWarning: divide by zero encountered in log
#   kernel = (topic_given_term * np.log((topic_given_term.T / topic_proportion).T))
# C:\Users\THINKPAD\Anaconda3\lib\site-packages\pyLDAvis\_prepare.py:240: RuntimeWarning: divide by zero encountered in log
#   log_lift = np.log(topic_term_dists / term_proportion)
# C:\Users\THINKPAD\Anaconda3\lib\site-packages\pyLDAvis\_prepare.py:241: RuntimeWarning: divide by zero encountered in log
#   log_ttd = np.log(topic_term_dists)

# %%
of = codecs.open('C:/Users/THINKPAD/Downloads/coherence_values_asym.txt', 'w', 'utf-8')
for run_number in range(3):
    rs = 1
    for tn in range(5, 42):
        np.random.seed(123)
        model = gensim.models.wrappers.LdaMallet(mallet_path,
                                                 corpus=corpus,
                                                 num_topics=tn,
                                                 id2word=dictionary,
                                                 optimize_interval = 10,
                                                 random_seed=rs+run_number)
        rs += 1
        lda = gensim.models.wrappers.ldamallet.malletmodel2ldamodel(model)
        lda.save(('C:/Users/THINKPAD/Downloads/lda_modellek_asym/lda_t' + str(tn) + '_r' + str(run_number) +'.model'), ignore=())

        coherence_model = CoherenceModel(model=model,
                                         texts=txts,
                                         dictionary=dictionary,
                                         coherence='c_v')
        coherence_value = coherence_model.get_coherence()
        exp =  'topic ' +str(tn) + ' run' + str(run_number) + ' c_v: ' + str(coherence_value) + '\n'
        of.write(exp)
of.close()

# %%
cv2 = pd.read_excel("cv_values_asym.xlsx")
cv2
# Out:
#     Topik      Run0      Run1      Run2
# 0       5  0.340179  0.338653  0.325555
# 1       6  0.347587  0.354321  0.351800
# 2       7  0.367404  0.355755  0.371595
# 3       8  0.372871  0.377738  0.377347
# 4       9  0.398074  0.415013  0.380930
# 5      10  0.401443  0.407512  0.401540
# 6      11  0.413108  0.419274  0.415027
# 7      12  0.401966  0.403492  0.424864
# 8      13  0.443651  0.424685  0.426937
# 9      14  0.447634  0.434660  0.429163
# 10     15  0.427947  0.451653  0.440355
# 11     16  0.447728  0.439483  0.456045
# 12     17  0.451639  0.449323  0.450266
# 13     18  0.452966  0.458344  0.464793
# 14     19  0.460732  0.461183  0.460243
# 15     20  0.468147  0.458055  0.466373
# 16     21  0.472752  0.466464  0.461706
# 17     22  0.468606  0.470052  0.472519
# 18     23  0.479763  0.478461  0.480186
# 19     24  0.477352  0.477569  0.488714
# 20     25  0.482715  0.484962  0.476584
# 21     26  0.474610  0.480716  0.480446
# 22     27  0.481967  0.479824  0.478695
# 23     28  0.484185  0.496362  0.491254
# 24     29  0.494332  0.488664  0.489771
# 25     30  0.482802  0.498706  0.486404
# 26     31  0.489349  0.493123  0.482562
# 27     32  0.496698  0.493608  0.494031
# 28     33  0.497987  0.506037  0.500525
# 29     34  0.500615  0.502013  0.493215
# 30     35  0.496857  0.497379  0.496452
# 31     36  0.499241  0.493657  0.498012
# 32     37  0.505405  0.500455  0.500168
# 33     38  0.496113  0.496635  0.513667
# 34     39  0.502288  0.497730  0.495310
# 35     40  0.510972  0.503480  0.497691
# 36     41  0.496352  0.511275  0.497632

# %%
from matplotlib.pyplot import figure
import matplotlib.pyplot as plt

plt.figure(figsize=(15, 12))
cv2.plot(x="Topik", y=["Run0", "Run1", "Run2"], grid = True)
plt.xlabel('Topikok száma')
plt.ylabel('C_v érték')
plt.savefig("cv41_values_asym.png", dpi = 300)
